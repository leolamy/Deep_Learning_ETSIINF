# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1:
# - Alumno 2:
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import requests
import zipfile

url = 'https://drive.upm.es/s/2DDPE2zHw5dbM3G/download'
zip_name = 'dataset.zip'

r = requests.get(url, stream=True)
with open(zip_name, 'wb') as f:
    for chunk in r.iter_content(chunk_size=1024):
        f.write(chunk)

if os.path.getsize(zip_name) < 10000:
    print(f"ERREUR : Le fichier {zip_name} est trop petit. Le lien est invalide ou nécessite une connexion.")
else:
    with zipfile.ZipFile(zip_name, 'r') as z:
        z.extractall(".") 

    target_file = 'xview_ann_train.json'
    found_path = None
    
    for root, dirs, files in os.walk("."):
        if target_file in files:
            found_path = os.path.join(root, target_file)
            break
    
    if found_path:
        print(f"SUCCÈS : Fichier trouvé à : {found_path}")
        
        import json
        json_file = found_path 
        
        with open(json_file) as ifs:
            json_data = json.load(ifs)
        print("Base de données chargée avec succès !")
        
    else:
        print(f"ERREUR : {target_file} reste introuvable après extraction.")
# Out:
# SUCCÈS : Fichier trouvé à : ./xview_recognition/xview_ann_train.json
# Base de données chargée avec succès !

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.5)

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('./xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = './xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense, Activation, Flatten, Input, Resizing, MaxPooling2D
#from tensorflow.keras.losses import CategoricalFocalCrossentropy
#from tensorflow.keras.optimizers import Adam, AdamW
#from tensorflow.keras.activations import swish
#import tensorflow as tf
#
#model = Sequential()
#model.add(Input(shape=(224, 224, 3)))
#model.add(MaxPooling2D(pool_size=(4, 4)))
#model.add(Flatten())
#
## Layer 1
#model.add(Dense(384, kernel_initializer='he_normal')) 
##model.add(BatchNormalization())
#model.add(Activation('swish')) 
##model.add(Dropout(0.4)) 
#
## Layer 2
#model.add(Dense(192, kernel_initializer='he_normal')) 
##model.add(BatchNormalization())
#model.add(Activation('swish'))
##model.add(Dropout(0.4))
#
## Layer 3
#model.add(Dense(96, kernel_initializer='he_normal')) 
##model.add(BatchNormalization())
#model.add(Activation('swish'))
##model.add(Dropout(0.4))
#
## Output
#model.add(Dense(len(categories)))
#model.add(Activation('softmax'))
#
#lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
#    initial_learning_rate=0.001, 
#    decay_steps=50 * (len(anns_train) // 32)
#)
#
#model.compile(
#    optimizer=AdamW(learning_rate=lr_schedule, weight_decay=0.001), 
#    loss=CategoricalFocalCrossentropy(alpha=0.25, gamma=2.5), 
#    metrics=['accuracy']
#)
#model.summary()

# %%
#from tensorflow.keras.optimizers import Adam
#
## Learning rate is changed to 0.001
#opt = Adam(learning_rate=lr_schedule, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
#model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Input, MaxPooling2D
from tensorflow.keras.losses import CategoricalFocalCrossentropy
from tensorflow.keras.optimizers import AdamW
import tensorflow as tf

model = Sequential()
model.add(Input(shape=(224, 224, 3)))

# On garde le Pooling 4x4 qui marche bien
model.add(MaxPooling2D(pool_size=(4, 4))) 
model.add(Flatten())

# Layer 1 : On réduit encore (256 suffisent largement après un pooling 4x4)
model.add(Dense(256, kernel_initializer='he_normal')) 
model.add(Activation('swish')) 

# Layer 2 : Le goulot d'étranglement (Bottleneck)
# Force le modèle à résumer l'image en seulement 64 concepts
model.add(Dense(64, kernel_initializer='he_normal'))
model.add(Activation('swish'))

# Output Directement après (Pas de 3ème couche cachée inutile)
model.add(Dense(len(categories)))
model.add(Activation('softmax'))

# Scheduler
lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=0.001, 
    decay_steps=50 * (len(anns_train) // 32)
)

model.compile(
    # Weight Decay agressif (0.005) pour tuer l'overfitting
    optimizer=AdamW(learning_rate=lr_schedule, weight_decay=0.005),
    loss=CategoricalFocalCrossentropy(alpha=0.25, gamma=2.0), 
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 56, 56, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 9408)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 256)            │     2,408,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 13)             │           845 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 13)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,425,997 (9.25 MB)
#  Trainable params: 2,425,997 (9.25 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
#reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=10, verbose=1)
early_stop = EarlyStopping('val_accuracy', patience=40, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                # Load image
                img = load_geoimage(filename)
                # regularization
                img = img.astype(np.float32) / 255.0
                images.append(img)
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 32 # change to 32 to stabilize the gradients
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model')
epochs = 50 # model still improving after 20 epochs -> stabilization
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/50
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.2893 - loss: 0.4614
# Epoch 1: val_accuracy improved from -inf to 0.39733, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 53s 97ms/step - accuracy: 0.2894 - loss: 0.4613 - val_accuracy: 0.3973 - val_loss: 0.3272
# Epoch 2/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4008 - loss: 0.3116
# Epoch 2: val_accuracy improved from 0.39733 to 0.40000, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 52s 99ms/step - accuracy: 0.4008 - loss: 0.3116 - val_accuracy: 0.4000 - val_loss: 0.3155
# Epoch 3/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4413 - loss: 0.2870
# Epoch 3: val_accuracy improved from 0.40000 to 0.44053, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - accuracy: 0.4413 - loss: 0.2870 - val_accuracy: 0.4405 - val_loss: 0.2860
# Epoch 4/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4487 - loss: 0.2774
# Epoch 4: val_accuracy improved from 0.44053 to 0.46187, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - accuracy: 0.4487 - loss: 0.2774 - val_accuracy: 0.4619 - val_loss: 0.2759
# Epoch 5/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4693 - loss: 0.2640
# Epoch 5: val_accuracy did not improve from 0.46187
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.4693 - loss: 0.2640 - val_accuracy: 0.4427 - val_loss: 0.2884
# Epoch 6/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4751 - loss: 0.2585
# Epoch 6: val_accuracy improved from 0.46187 to 0.47253, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 51s 96ms/step - accuracy: 0.4751 - loss: 0.2585 - val_accuracy: 0.4725 - val_loss: 0.2609
# Epoch 7/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4807 - loss: 0.2531
# Epoch 7: val_accuracy improved from 0.47253 to 0.48587, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 90ms/step - accuracy: 0.4807 - loss: 0.2531 - val_accuracy: 0.4859 - val_loss: 0.2640
# Epoch 8/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4934 - loss: 0.2420
# Epoch 8: val_accuracy did not improve from 0.48587
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.4934 - loss: 0.2420 - val_accuracy: 0.4523 - val_loss: 0.2751
# Epoch 9/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5098 - loss: 0.2368
# Epoch 9: val_accuracy improved from 0.48587 to 0.49973, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.5098 - loss: 0.2368 - val_accuracy: 0.4997 - val_loss: 0.2607
# Epoch 10/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5158 - loss: 0.2317
# Epoch 10: val_accuracy did not improve from 0.49973
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 88ms/step - accuracy: 0.5158 - loss: 0.2317 - val_accuracy: 0.4517 - val_loss: 0.2782
# Epoch 11/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5183 - loss: 0.2296
# Epoch 11: val_accuracy improved from 0.49973 to 0.50027, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.5183 - loss: 0.2296 - val_accuracy: 0.5003 - val_loss: 0.2452
# Epoch 12/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5294 - loss: 0.2226
# Epoch 12: val_accuracy did not improve from 0.50027
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.5294 - loss: 0.2226 - val_accuracy: 0.4896 - val_loss: 0.2560
# Epoch 13/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5368 - loss: 0.2137
# Epoch 13: val_accuracy improved from 0.50027 to 0.50240, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.5368 - loss: 0.2137 - val_accuracy: 0.5024 - val_loss: 0.2449
# Epoch 14/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5390 - loss: 0.2153
# Epoch 14: val_accuracy did not improve from 0.50240
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.5390 - loss: 0.2153 - val_accuracy: 0.4800 - val_loss: 0.2547
# Epoch 15/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5515 - loss: 0.2073
# Epoch 15: val_accuracy improved from 0.50240 to 0.51680, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.5515 - loss: 0.2073 - val_accuracy: 0.5168 - val_loss: 0.2516
# Epoch 16/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5505 - loss: 0.2054
# Epoch 16: val_accuracy did not improve from 0.51680
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.5505 - loss: 0.2054 - val_accuracy: 0.5008 - val_loss: 0.2500
# Epoch 17/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5638 - loss: 0.1957
# Epoch 17: val_accuracy did not improve from 0.51680
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 88ms/step - accuracy: 0.5638 - loss: 0.1958 - val_accuracy: 0.5008 - val_loss: 0.2477
# Epoch 18/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5678 - loss: 0.1957
# Epoch 18: val_accuracy did not improve from 0.51680
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 88ms/step - accuracy: 0.5678 - loss: 0.1957 - val_accuracy: 0.5120 - val_loss: 0.2511
# Epoch 19/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5712 - loss: 0.1916
# Epoch 19: val_accuracy improved from 0.51680 to 0.53600, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 90ms/step - accuracy: 0.5712 - loss: 0.1916 - val_accuracy: 0.5360 - val_loss: 0.2365
# Epoch 20/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5921 - loss: 0.1837
# Epoch 20: val_accuracy did not improve from 0.53600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.5920 - loss: 0.1838 - val_accuracy: 0.5227 - val_loss: 0.2484
# Epoch 21/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5847 - loss: 0.1855
# Epoch 21: val_accuracy did not improve from 0.53600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.5847 - loss: 0.1855 - val_accuracy: 0.5237 - val_loss: 0.2458
# Epoch 22/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5970 - loss: 0.1775
# Epoch 22: val_accuracy did not improve from 0.53600
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.5971 - loss: 0.1775 - val_accuracy: 0.4821 - val_loss: 0.2584
# Epoch 23/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5993 - loss: 0.1770
# Epoch 23: val_accuracy improved from 0.53600 to 0.54453, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.5993 - loss: 0.1770 - val_accuracy: 0.5445 - val_loss: 0.2387
# Epoch 24/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6055 - loss: 0.1733
# Epoch 24: val_accuracy did not improve from 0.54453
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.6055 - loss: 0.1733 - val_accuracy: 0.5440 - val_loss: 0.2410
# Epoch 25/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6215 - loss: 0.1646
# Epoch 25: val_accuracy did not improve from 0.54453
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.6215 - loss: 0.1646 - val_accuracy: 0.5429 - val_loss: 0.2484
# Epoch 26/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6258 - loss: 0.1613
# Epoch 26: val_accuracy improved from 0.54453 to 0.55040, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.6257 - loss: 0.1613 - val_accuracy: 0.5504 - val_loss: 0.2363
# Epoch 27/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6317 - loss: 0.1609
# Epoch 27: val_accuracy did not improve from 0.55040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.6317 - loss: 0.1609 - val_accuracy: 0.5472 - val_loss: 0.2391
# Epoch 28/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6345 - loss: 0.1594
# Epoch 28: val_accuracy did not improve from 0.55040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 88ms/step - accuracy: 0.6345 - loss: 0.1594 - val_accuracy: 0.5504 - val_loss: 0.2394
# Epoch 29/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6357 - loss: 0.1547
# Epoch 29: val_accuracy did not improve from 0.55040
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 48s 90ms/step - accuracy: 0.6357 - loss: 0.1547 - val_accuracy: 0.5413 - val_loss: 0.2437
# Epoch 30/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6482 - loss: 0.1522
# Epoch 30: val_accuracy improved from 0.55040 to 0.55520, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 90ms/step - accuracy: 0.6482 - loss: 0.1522 - val_accuracy: 0.5552 - val_loss: 0.2409
# Epoch 31/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6526 - loss: 0.1483
# Epoch 31: val_accuracy improved from 0.55520 to 0.55893, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.6526 - loss: 0.1483 - val_accuracy: 0.5589 - val_loss: 0.2433
# Epoch 32/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6496 - loss: 0.1486
# Epoch 32: val_accuracy did not improve from 0.55893
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.6496 - loss: 0.1486 - val_accuracy: 0.5349 - val_loss: 0.2447
# Epoch 33/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6632 - loss: 0.1427
# Epoch 33: val_accuracy did not improve from 0.55893
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 90ms/step - accuracy: 0.6631 - loss: 0.1427 - val_accuracy: 0.5451 - val_loss: 0.2464
# Epoch 34/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6604 - loss: 0.1430
# Epoch 34: val_accuracy did not improve from 0.55893
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 88ms/step - accuracy: 0.6605 - loss: 0.1430 - val_accuracy: 0.5568 - val_loss: 0.2407
# Epoch 35/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6655 - loss: 0.1376
# Epoch 35: val_accuracy did not improve from 0.55893
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 90ms/step - accuracy: 0.6655 - loss: 0.1376 - val_accuracy: 0.5413 - val_loss: 0.2497
# Epoch 36/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6708 - loss: 0.1375
# Epoch 36: val_accuracy did not improve from 0.55893
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.6708 - loss: 0.1375 - val_accuracy: 0.5525 - val_loss: 0.2443
# Epoch 37/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6781 - loss: 0.1368
# Epoch 37: val_accuracy did not improve from 0.55893
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.6781 - loss: 0.1368 - val_accuracy: 0.5413 - val_loss: 0.2429
# Epoch 38/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6817 - loss: 0.1336
# Epoch 38: val_accuracy did not improve from 0.55893
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.6817 - loss: 0.1336 - val_accuracy: 0.5531 - val_loss: 0.2481
# Epoch 39/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6850 - loss: 0.1303
# Epoch 39: val_accuracy did not improve from 0.55893
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.6849 - loss: 0.1303 - val_accuracy: 0.5445 - val_loss: 0.2477
# Epoch 40/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6811 - loss: 0.1290
# Epoch 40: val_accuracy did not improve from 0.55893
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.6811 - loss: 0.1290 - val_accuracy: 0.5552 - val_loss: 0.2459
# Epoch 41/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6880 - loss: 0.1276
# Epoch 41: val_accuracy did not improve from 0.55893
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 90ms/step - accuracy: 0.6880 - loss: 0.1276 - val_accuracy: 0.5488 - val_loss: 0.2452
# Epoch 42/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6893 - loss: 0.1275
# Epoch 42: val_accuracy improved from 0.55893 to 0.56000, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.6893 - loss: 0.1275 - val_accuracy: 0.5600 - val_loss: 0.2452
# Epoch 43/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7005 - loss: 0.1250
# Epoch 43: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 87ms/step - accuracy: 0.7005 - loss: 0.1250 - val_accuracy: 0.5536 - val_loss: 0.2469
# Epoch 44/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6964 - loss: 0.1248
# Epoch 44: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 87ms/step - accuracy: 0.6964 - loss: 0.1248 - val_accuracy: 0.5547 - val_loss: 0.2465
# Epoch 45/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6976 - loss: 0.1227
# Epoch 45: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.6976 - loss: 0.1227 - val_accuracy: 0.5525 - val_loss: 0.2465
# Epoch 46/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7007 - loss: 0.1226
# Epoch 46: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.7007 - loss: 0.1226 - val_accuracy: 0.5547 - val_loss: 0.2456
# Epoch 47/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7044 - loss: 0.1219
# Epoch 47: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 46s 88ms/step - accuracy: 0.7044 - loss: 0.1219 - val_accuracy: 0.5525 - val_loss: 0.2461
# Epoch 48/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7010 - loss: 0.1217
# Epoch 48: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 88ms/step - accuracy: 0.7011 - loss: 0.1217 - val_accuracy: 0.5531 - val_loss: 0.2462
# Epoch 49/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7000 - loss: 0.1248
# Epoch 49: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.7000 - loss: 0.1248 - val_accuracy: 0.5531 - val_loss: 0.2462
# Epoch 50/50
# 527/528 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7047 - loss: 0.1203
# Epoch 50: val_accuracy did not improve from 0.56000
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 47s 89ms/step - accuracy: 0.7047 - loss: 0.1203 - val_accuracy: 0.5536 - val_loss: 0.2462
# Best validation model: epoch 42  - val_accuracy 0.5600000023841858

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np

model.load_weights('model.keras')
y_true, y_pred = [], []
for ann in anns_valid:
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 48.107%
# Mean Recall: 44.672%
# Mean Precision: 50.883%
# > Cargo plane: Recall: 76.271% Precision: 52.941% Specificity: 97.797% Dice: 62.500%
# > Small car: Recall: 59.574% Precision: 76.562% Specificity: 96.119% Dice: 67.009%
# > Bus: Recall: 64.368% Precision: 30.854% Specificity: 85.244% Dice: 41.713%
# > Truck: Recall: 22.822% Precision: 38.462% Specificity: 94.614% Dice: 28.646%
# > Motorboat: Recall: 53.211% Precision: 23.200% Specificity: 89.128% Dice: 32.312%
# > Fishing vessel: Recall: 4.110% Precision: 75.000% Specificity: 99.945% Dice: 7.792%
# > Dump truck: Recall: 50.847% Precision: 49.180% Specificity: 96.471% Dice: 50.000%
# > Excavator: Recall: 50.617% Precision: 56.164% Specificity: 98.216% Dice: 53.247%
# > Building: Recall: 60.055% Precision: 63.930% Specificity: 91.865% Dice: 61.932%
# > Helipad: Recall: 22.222% Precision: 12.500% Specificity: 99.250% Dice: 16.000%
# > Storage tank: Recall: 35.526% Precision: 50.943% Specificity: 96.982% Dice: 41.860%
# > Shipping container: Recall: 31.111% Precision: 42.857% Specificity: 96.782% Dice: 36.052%
# > Pylon: Recall: 50.000% Precision: 88.889% Specificity: 99.891% Dice: 64.000%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
root_dir = './xview_recognition/'
test_dir = os.path.join(root_dir, 'xview_test')
for (dirpath, dirnames, filenames) in os.walk(test_dir):
    for filename in filenames:
        rel_dir = os.path.relpath(dirpath, root_dir)
        clean_filename = os.path.join(rel_dir, filename)
        image = GenericImage(clean_filename)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = os.path.basename(dirpath)
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
import json
with open('prediction.json', 'w') as f:
    json.dump(predictions_data, f)
