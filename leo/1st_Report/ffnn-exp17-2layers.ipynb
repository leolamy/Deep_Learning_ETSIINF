# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1:
# - Alumno 2:
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import requests
import zipfile

url = 'https://drive.upm.es/s/2DDPE2zHw5dbM3G/download'
zip_name = 'dataset.zip'

r = requests.get(url, stream=True)
with open(zip_name, 'wb') as f:
    for chunk in r.iter_content(chunk_size=1024):
        f.write(chunk)

if os.path.getsize(zip_name) < 10000:
    print(f"ERREUR : Le fichier {zip_name} est trop petit. Le lien est invalide ou nécessite une connexion.")
else:
    with zipfile.ZipFile(zip_name, 'r') as z:
        z.extractall(".") 

    target_file = 'xview_ann_train.json'
    found_path = None
    
    for root, dirs, files in os.walk("."):
        if target_file in files:
            found_path = os.path.join(root, target_file)
            break
    
    if found_path:
        print(f"SUCCÈS : Fichier trouvé à : {found_path}")
        
        import json
        json_file = found_path 
        
        with open(json_file) as ifs:
            json_data = json.load(ifs)
        print("Base de données chargée avec succès !")
        
    else:
        print(f"ERREUR : {target_file} reste introuvable après extraction.")
# Out:
# SUCCÈS : Fichier trouvé à : ./xview_recognition/xview_ann_train.json
# Base de données chargée avec succès !

# %%
import tensorflow as tf

# Vérifie la présence de processeurs graphiques
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    try:
        # Configuration pour ne pas allouer toute la mémoire d'un coup
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"GPU activé : {len(gpus)} processeur(s) détecté(s)")
    except RuntimeError as e:
        print(e)
else:
    print("GPU non détecté. Activez l'accélérateur dans les réglages du notebook.")
# Out:
# []

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.5)

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('./xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = './xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
labels = [img.objects[0].category for img in anns]
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True, stratify=labels)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 16871
# Number of validation images: 1875

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Input, Normalization
from tensorflow.keras.losses import CategoricalFocalCrossentropy
from tensorflow.keras.optimizers import Nadam 
import tensorflow as tf

#norm_layer = Normalization()

model = Sequential()
model.add(Input(shape=(32, 32, 3)))
#model.add(norm_layer)
model.add(Flatten())

# Layer 1
model.add(Dense(256, kernel_initializer='he_normal')) 
#model.add(BatchNormalization())
model.add(Activation('swish')) 
#model.add(Dropout(0.4)) 

# Layer 2
model.add(Dense(512, kernel_initializer='he_normal')) 
#model.add(BatchNormalization())
model.add(Activation('swish')) 
#model.add(Dropout(0.4)) 

# Layer 3
#model.add(Dense(256, kernel_initializer='he_normal')) 
#model.add(BatchNormalization())
#model.add(Activation('swish')) 
#model.add(Dropout(0.4)) 

# Output
model.add(Dense(len(categories)))
model.add(Activation('softmax'))

lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=0.001, 
    decay_steps=40 * (len(anns_train) // 32)
)

model.compile(
    optimizer=Nadam(learning_rate=lr_schedule, weight_decay=1e-4),
    loss=CategoricalFocalCrossentropy(alpha=0.25, gamma=2.0), 
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_3 (Flatten)             │ (None, 9408)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 1024)           │     9,634,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_14 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 13)             │         3,341 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 13)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,294,285 (39.27 MB)
#  Trainable params: 10,294,285 (39.27 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#from tensorflow.keras.optimizers import Adam
#
## Learning rate is changed to 0.001
#opt = Adam(learning_rate=lr_schedule, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
#model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
#reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=10, verbose=1)
early_stop = EarlyStopping('val_accuracy', patience=20, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                # Load image
                img = load_geoimage(filename)
                # Convertir en tenseur Tensorflow pour le traitement
                img_tensor = tf.convert_to_tensor(img)
                # Convertir en float32 et normaliser entre 0 et 1
                img_tensor = tf.image.convert_image_dtype(img_tensor, tf.float32)
                # Redimensionnement via bicubic (+ précis)
                img_resized = tf.image.resize(img_tensor, [32, 32], method='bicubic')
                # On repasse en Numpy pour construire le batch
                images.append(img_resized.numpy())                
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 128 # change to 32 to stabilize the gradients
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model')
epochs = 100 # model still improving after 20 epochs -> stabilization
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.3345 - loss: 0.4115
# Epoch 1: val_accuracy improved from -inf to 0.37813, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 107s 199ms/step - accuracy: 0.3346 - loss: 0.4113 - val_accuracy: 0.3781 - val_loss: 0.3458
# Epoch 2/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4518 - loss: 0.2749
# Epoch 2: val_accuracy improved from 0.37813 to 0.42187, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 142s 269ms/step - accuracy: 0.4518 - loss: 0.2749 - val_accuracy: 0.4219 - val_loss: 0.2900
# Epoch 3/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4649 - loss: 0.2604
# Epoch 3: val_accuracy did not improve from 0.42187
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 142s 269ms/step - accuracy: 0.4649 - loss: 0.2604 - val_accuracy: 0.4149 - val_loss: 0.2901
# Epoch 4/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.5014 - loss: 0.2420
# Epoch 4: val_accuracy improved from 0.42187 to 0.46987, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 104s 198ms/step - accuracy: 0.5014 - loss: 0.2420 - val_accuracy: 0.4699 - val_loss: 0.2714
# Epoch 5/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.5249 - loss: 0.2300
# Epoch 5: val_accuracy improved from 0.46987 to 0.47200, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 108s 204ms/step - accuracy: 0.5249 - loss: 0.2300 - val_accuracy: 0.4720 - val_loss: 0.2512
# Epoch 6/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.5435 - loss: 0.2174
# Epoch 6: val_accuracy did not improve from 0.47200
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 105s 199ms/step - accuracy: 0.5435 - loss: 0.2174 - val_accuracy: 0.4293 - val_loss: 0.3142
# Epoch 7/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.5636 - loss: 0.2087
# Epoch 7: val_accuracy improved from 0.47200 to 0.47787, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 138s 262ms/step - accuracy: 0.5636 - loss: 0.2087 - val_accuracy: 0.4779 - val_loss: 0.2641
# Epoch 8/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.5714 - loss: 0.1990
# Epoch 8: val_accuracy improved from 0.47787 to 0.50187, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 106s 201ms/step - accuracy: 0.5714 - loss: 0.1990 - val_accuracy: 0.5019 - val_loss: 0.2328
# Epoch 9/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.5844 - loss: 0.1905
# Epoch 9: val_accuracy improved from 0.50187 to 0.50933, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 136s 258ms/step - accuracy: 0.5844 - loss: 0.1905 - val_accuracy: 0.5093 - val_loss: 0.2438
# Epoch 10/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.6036 - loss: 0.1765
# Epoch 10: val_accuracy improved from 0.50933 to 0.52160, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 115s 219ms/step - accuracy: 0.6036 - loss: 0.1765 - val_accuracy: 0.5216 - val_loss: 0.2444
# Epoch 11/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6165 - loss: 0.1686
# Epoch 11: val_accuracy did not improve from 0.52160
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 107s 204ms/step - accuracy: 0.6165 - loss: 0.1687 - val_accuracy: 0.5205 - val_loss: 0.2272
# Epoch 12/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6256 - loss: 0.1657
# Epoch 12: val_accuracy improved from 0.52160 to 0.53440, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 121s 229ms/step - accuracy: 0.6256 - loss: 0.1657 - val_accuracy: 0.5344 - val_loss: 0.2297
# Epoch 13/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6435 - loss: 0.1572
# Epoch 13: val_accuracy did not improve from 0.53440
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 123s 233ms/step - accuracy: 0.6435 - loss: 0.1572 - val_accuracy: 0.5216 - val_loss: 0.2298
# Epoch 14/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6649 - loss: 0.1489
# Epoch 14: val_accuracy improved from 0.53440 to 0.54933, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 124s 235ms/step - accuracy: 0.6649 - loss: 0.1489 - val_accuracy: 0.5493 - val_loss: 0.2237
# Epoch 15/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.6678 - loss: 0.1440
# Epoch 15: val_accuracy improved from 0.54933 to 0.55307, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 119s 225ms/step - accuracy: 0.6678 - loss: 0.1440 - val_accuracy: 0.5531 - val_loss: 0.2227
# Epoch 16/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.6809 - loss: 0.1341
# Epoch 16: val_accuracy did not improve from 0.55307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 101s 190ms/step - accuracy: 0.6809 - loss: 0.1341 - val_accuracy: 0.5515 - val_loss: 0.2174
# Epoch 17/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6941 - loss: 0.1271
# Epoch 17: val_accuracy did not improve from 0.55307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 101s 191ms/step - accuracy: 0.6941 - loss: 0.1271 - val_accuracy: 0.5504 - val_loss: 0.2204
# Epoch 18/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7054 - loss: 0.1210
# Epoch 18: val_accuracy did not improve from 0.55307
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 139s 263ms/step - accuracy: 0.7054 - loss: 0.1210 - val_accuracy: 0.5531 - val_loss: 0.2262
# Epoch 19/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7140 - loss: 0.1183
# Epoch 19: val_accuracy improved from 0.55307 to 0.56107, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 86s 162ms/step - accuracy: 0.7140 - loss: 0.1183 - val_accuracy: 0.5611 - val_loss: 0.2141
# Epoch 20/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7436 - loss: 0.1058
# Epoch 20: val_accuracy improved from 0.56107 to 0.57920, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 91s 173ms/step - accuracy: 0.7435 - loss: 0.1058 - val_accuracy: 0.5792 - val_loss: 0.2183
# Epoch 21/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7509 - loss: 0.1025
# Epoch 21: val_accuracy improved from 0.57920 to 0.58293, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 142s 269ms/step - accuracy: 0.7509 - loss: 0.1025 - val_accuracy: 0.5829 - val_loss: 0.2105
# Epoch 22/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7610 - loss: 0.0982
# Epoch 22: val_accuracy did not improve from 0.58293
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 81s 154ms/step - accuracy: 0.7610 - loss: 0.0982 - val_accuracy: 0.5803 - val_loss: 0.2084
# Epoch 23/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.7732 - loss: 0.0932
# Epoch 23: val_accuracy did not improve from 0.58293
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 155ms/step - accuracy: 0.7732 - loss: 0.0932 - val_accuracy: 0.5744 - val_loss: 0.2164
# Epoch 24/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.7844 - loss: 0.0877
# Epoch 24: val_accuracy improved from 0.58293 to 0.58400, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 95s 180ms/step - accuracy: 0.7844 - loss: 0.0877 - val_accuracy: 0.5840 - val_loss: 0.2125
# Epoch 25/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7946 - loss: 0.0841
# Epoch 25: val_accuracy did not improve from 0.58400
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 141s 268ms/step - accuracy: 0.7946 - loss: 0.0841 - val_accuracy: 0.5771 - val_loss: 0.2180
# Epoch 26/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8152 - loss: 0.0775
# Epoch 26: val_accuracy did not improve from 0.58400
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 82s 156ms/step - accuracy: 0.8152 - loss: 0.0775 - val_accuracy: 0.5712 - val_loss: 0.2171
# Epoch 27/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8227 - loss: 0.0736
# Epoch 27: val_accuracy improved from 0.58400 to 0.59147, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 102s 193ms/step - accuracy: 0.8227 - loss: 0.0736 - val_accuracy: 0.5915 - val_loss: 0.2137
# Epoch 28/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.8284 - loss: 0.0714
# Epoch 28: val_accuracy did not improve from 0.59147
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 201s 380ms/step - accuracy: 0.8284 - loss: 0.0714 - val_accuracy: 0.5829 - val_loss: 0.2145
# Epoch 29/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8357 - loss: 0.0692
# Epoch 29: val_accuracy did not improve from 0.59147
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 117s 221ms/step - accuracy: 0.8357 - loss: 0.0692 - val_accuracy: 0.5813 - val_loss: 0.2182
# Epoch 30/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8481 - loss: 0.0658
# Epoch 30: val_accuracy did not improve from 0.59147
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 99s 188ms/step - accuracy: 0.8481 - loss: 0.0658 - val_accuracy: 0.5888 - val_loss: 0.2149
# Epoch 31/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8450 - loss: 0.0650
# Epoch 31: val_accuracy did not improve from 0.59147
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 102s 193ms/step - accuracy: 0.8450 - loss: 0.0650 - val_accuracy: 0.5845 - val_loss: 0.2131
# Epoch 32/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8618 - loss: 0.0598
# Epoch 32: val_accuracy did not improve from 0.59147
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 107s 203ms/step - accuracy: 0.8618 - loss: 0.0598 - val_accuracy: 0.5904 - val_loss: 0.2186
# Epoch 33/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.8676 - loss: 0.0596
# Epoch 33: val_accuracy did not improve from 0.59147
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 147s 278ms/step - accuracy: 0.8676 - loss: 0.0596 - val_accuracy: 0.5872 - val_loss: 0.2127
# Epoch 34/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8722 - loss: 0.0565
# Epoch 34: val_accuracy did not improve from 0.59147
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 125s 238ms/step - accuracy: 0.8722 - loss: 0.0565 - val_accuracy: 0.5915 - val_loss: 0.2156
# Epoch 35/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8734 - loss: 0.0567
# Epoch 35: val_accuracy improved from 0.59147 to 0.59467, saving model to model.keras
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 122s 232ms/step - accuracy: 0.8734 - loss: 0.0567 - val_accuracy: 0.5947 - val_loss: 0.2156
# Epoch 36/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8762 - loss: 0.0563
# Epoch 36: val_accuracy did not improve from 0.59467
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 106s 201ms/step - accuracy: 0.8762 - loss: 0.0563 - val_accuracy: 0.5920 - val_loss: 0.2139
# Epoch 37/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8771 - loss: 0.0552
# Epoch 37: val_accuracy did not improve from 0.59467
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 105s 199ms/step - accuracy: 0.8771 - loss: 0.0552 - val_accuracy: 0.5936 - val_loss: 0.2150
# Epoch 38/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8844 - loss: 0.0537
# Epoch 38: val_accuracy did not improve from 0.59467
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 123s 234ms/step - accuracy: 0.8844 - loss: 0.0537 - val_accuracy: 0.5936 - val_loss: 0.2142
# Epoch 39/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8779 - loss: 0.0552
# Epoch 39: val_accuracy did not improve from 0.59467
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 109s 207ms/step - accuracy: 0.8779 - loss: 0.0552 - val_accuracy: 0.5920 - val_loss: 0.2141
# Epoch 40/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.8852 - loss: 0.0528
# Epoch 40: val_accuracy did not improve from 0.59467
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 107s 203ms/step - accuracy: 0.8852 - loss: 0.0528 - val_accuracy: 0.5915 - val_loss: 0.2141
# Epoch 41/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8831 - loss: 0.0551
# Epoch 41: val_accuracy did not improve from 0.59467
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 142s 270ms/step - accuracy: 0.8831 - loss: 0.0551 - val_accuracy: 0.5915 - val_loss: 0.2141
# Epoch 42/42
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8816 - loss: 0.0543
# Epoch 42: val_accuracy did not improve from 0.59467
# 528/528 ━━━━━━━━━━━━━━━━━━━━ 143s 272ms/step - accuracy: 0.8816 - loss: 0.0543 - val_accuracy: 0.5915 - val_loss: 0.2141
# Best validation model: epoch 35  - val_accuracy 0.5946666598320007

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np
import tensorflow as tf

model.load_weights('model.keras')
y_true, y_pred = [], []
all_images = []
temp_true_labels = []

print("Chargement des données de validation...")
for ann in anns_valid:
    # 1. Charger l'image brute
    image_raw = load_geoimage(ann.filename)
    
    # 2. Prétraitement IDENTIQUE à l'entraînement
    image_tensor = tf.convert_to_tensor(image_raw)
    image_tensor = tf.image.convert_image_dtype(image_tensor, tf.float32)
    # C'est cette ligne qui manquait :
    image_resized = tf.image.resize(image_tensor, [32, 32], method='bicubic')
    
    # Stocker pour chaque objet de l'image
    for obj_pred in ann.objects:
        all_images.append(image_resized.numpy())
        temp_true_labels.append(obj_pred.category)

if all_images:
    X_valid = np.array(all_images)
    print(f"Lancement de la prédiction sur {len(X_valid)} objets...")
    
    all_predictions = model.predict(X_valid, batch_size=64, verbose=1)
    
    category_names = list(categories.values())
    for i in range(len(all_predictions)):
        pred_category = category_names[np.argmax(all_predictions[i])]
        y_true.append(temp_true_labels[i])
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 59.467%
# Mean Recall: 53.411%
# Mean Precision: 56.207%
# > Cargo plane: Recall: 78.125% Precision: 92.593% Specificity: 99.779% Dice: 84.746%
# > Small car: Recall: 79.217% Precision: 72.253% Specificity: 93.454% Dice: 75.575%
# > Bus: Recall: 45.763% Precision: 45.763% Specificity: 94.346% Dice: 45.763%
# > Truck: Recall: 29.864% Precision: 33.673% Specificity: 92.140% Dice: 31.655%
# > Motorboat: Recall: 42.056% Precision: 62.500% Specificity: 98.473% Dice: 50.279%
# > Fishing vessel: Recall: 50.704% Precision: 66.667% Specificity: 99.002% Dice: 57.600%
# > Dump truck: Recall: 58.065% Precision: 53.731% Specificity: 96.459% Dice: 55.814%
# > Excavator: Recall: 56.962% Precision: 58.442% Specificity: 98.218% Dice: 57.692%
# > Building: Recall: 69.916% Precision: 64.194% Specificity: 90.765% Dice: 66.933%
# > Helipad: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Storage tank: Recall: 58.503% Precision: 56.579% Specificity: 96.181% Dice: 57.525%
# > Shipping container: Recall: 67.105% Precision: 57.627% Specificity: 95.647% Dice: 62.006%
# > Pylon: Recall: 58.065% Precision: 66.667% Specificity: 99.512% Dice: 62.069%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
root_dir = './xview_recognition/'
test_dir = os.path.join(root_dir, 'xview_test')
for (dirpath, dirnames, filenames) in os.walk(test_dir):
    for filename in filenames:
        rel_dir = os.path.relpath(dirpath, root_dir)
        clean_filename = os.path.join(rel_dir, filename)
        image = GenericImage(clean_filename)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = os.path.basename(dirpath)
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np
import tensorflow as tf

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
all_test_images = []
metadata = [] # Pour stocker (image_id, bbox) dans le même ordre que les images
ann_id = 0

print("Préparation des images de test...")
for idx, ann in enumerate(anns):
    image_data = {
        "image_id": ann.filename.split('/')[-1], 
        "filename": ann.filename, 
        "width": int(ann.tile[2]), 
        "height": int(ann.tile[3])
    }
    predictions_data["images"][idx] = image_data
    
    # Prétraitement (une seule fois par image source)
    image_raw = load_geoimage(ann.filename)
    image_tensor = tf.convert_to_tensor(image_raw)
    image_tensor = tf.image.convert_image_dtype(image_tensor, tf.float32)
    image_resized = tf.image.resize(image_tensor, [56,56], method='bicubic')
    img_final = image_resized.numpy()

    for obj_pred in ann.objects:
        all_test_images.append(img_final)
        metadata.append({
            "image_id": ann.filename.split('/')[-1],
            "bbox": [int(x) for x in obj_pred.bb]
        })

# Prédiction massive sur GPU
if all_test_images:
    X_test = np.array(all_test_images)
    print(f"Prédiction en cours sur {len(X_test)} détections...")
    
    # Utilisation du batch_size pour saturer les T4
    all_preds = model.predict(X_test, batch_size=64, verbose=1)
    
    category_names = list(categories.values())
    
    # Reconstruction du dictionnaire final
    for i, pred in enumerate(all_preds):
        pred_category = category_names[np.argmax(pred)]
        
        predictions_data["annotations"][ann_id] = {
            "image_id": metadata[i]["image_id"],
            "category_id": pred_category, 
            "bbox": metadata[i]["bbox"]
        }
        ann_id += 1
print("Test terminé.")
# Out:
# Génération des résultats...
# Terminé. 2365 annotations générées.

# %%
import json
with open('prediction.json', 'w') as f:
    json.dump(predictions_data, f)
