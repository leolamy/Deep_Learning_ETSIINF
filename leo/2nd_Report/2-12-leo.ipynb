# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1:
# - Alumno 2:
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import requests
import zipfile

url = 'https://drive.upm.es/s/2DDPE2zHw5dbM3G/download'
zip_name = 'dataset.zip'

r = requests.get(url, stream=True)
with open(zip_name, 'wb') as f:
    for chunk in r.iter_content(chunk_size=1024):
        f.write(chunk)

if os.path.getsize(zip_name) < 10000:
    print(f"ERREUR : Le fichier {zip_name} est trop petit. Le lien est invalide ou nécessite une connexion.")
else:
    with zipfile.ZipFile(zip_name, 'r') as z:
        z.extractall(".")

    target_file = 'xview_ann_train.json'
    found_path = None

    for root, dirs, files in os.walk("."):
        if target_file in files:
            found_path = os.path.join(root, target_file)
            break

    if found_path:
        print(f"SUCCÈS : Fichier trouvé à : {found_path}")

        import json
        json_file = found_path

        with open(json_file) as ifs:
            json_data = json.load(ifs)
        print("Base de données chargée avec succès !")

    else:
        print(f"ERREUR : {target_file} reste introuvable après extraction.")
# Out:
# SUCCÈS : Fichier trouvé à : ./xview_recognition/xview_ann_train.json
# Base de données chargée avec succès !

# %%
import tensorflow as tf

# Vérifie la présence de processeurs graphiques
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    try:
        # Configuration pour ne pas allouer toute la mémoire d'un coup
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"GPU activé : {len(gpus)} processeur(s) détecté(s)")
    except RuntimeError as e:
        print(e)
else:
    print("GPU non détecté. Activez l'accélérateur dans les réglages du notebook.")
# Out:
# 2026-02-22 14:43:41.468457: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771771421.680808      17 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771771421.738446      17 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771771422.248005      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771771422.248049      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771771422.248051      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771771422.248053      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# GPU non détecté. Activez l'accélérateur dans les réglages du notebook.
# 2026-02-22 14:44:08.985477: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.1)

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('./xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = './xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
labels = [img.objects[0].category for img in anns]
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.15, random_state=42, shuffle=True, stratify=labels)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 15934
# Number of validation images: 2812

# %%
from tensorflow.keras.layers import Dense, BatchNormalization, Activation, Dropout, Flatten, Input, Add, GaussianNoise
from tensorflow.keras.models import Model
import tensorflow as tf

def dense_residual_block(x, units, dropout_rate=0.1):
    shortcut = Dense(units, use_bias=False)(x)
    shortcut = BatchNormalization()(shortcut)

    out = Dense(units,  kernel_initializer='he_normal', use_bias=False)(x)
    out = BatchNormalization()(out)
    out = Activation('gelu')(out)
    out = Dropout(dropout_rate)(out)
    out = Dense(units,  kernel_initializer='he_normal', use_bias=False)(out)
    out = BatchNormalization()(out)

    out = Add()([out, shortcut])
    out = Activation('gelu')(out)
    return out

inputs = Input(shape=(96, 96, 3))
x = tf.keras.layers.RandomFlip("horizontal_and_vertical")(inputs)
x = tf.keras.layers.RandomRotation(0.25)(x)

x = GaussianNoise(stddev=0.1)(x)

x = Flatten()(x)

x = dense_residual_block(x, 1024, dropout_rate=0.15)
x = dense_residual_block(x, 1024, dropout_rate=0.15)
x = dense_residual_block(x, 512,  dropout_rate=0.15)
x = dense_residual_block(x, 256,  dropout_rate=0.15)

outputs = Dense(len(categories), activation='softmax')(x)
model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 96, 96, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_flip         │ (None, 96, 96, 3) │          0 │ input_layer[0][0] │
# │ (RandomFlip)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_rotation     │ (None, 96, 96, 3) │          0 │ random_flip[0][0] │
# │ (RandomRotation)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 27648)     │          0 │ random_rotation[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1024)      │ 28,311,552 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 1024)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1024)      │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1024)      │  1,048,576 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1024)      │ 28,311,552 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1024)      │      4,096 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1024)      │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1024)      │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1024)      │  1,048,576 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 1024)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1024)      │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1024)      │  1,048,576 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1024)      │  1,048,576 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1024)      │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 1024)      │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 512)       │    524,288 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 512)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 512)       │    262,144 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 512)       │    524,288 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 512)       │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 512)       │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 256)       │    131,072 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 256)       │     65,536 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 256)       │    131,072 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_11[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_9[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 256)       │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 256)       │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 13)        │      3,341 │ activation_7[0][… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 62,492,941 (238.39 MB)
#  Trainable params: 62,476,045 (238.33 MB)
#  Non-trainable params: 16,896 (66.00 KB)

# %%
#from tensorflow.keras.optimizers import Adam
#
## Learning rate is changed to 0.001
#opt = Adam(learning_rate=lr_schedule, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
#model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', save_best_only=True, mode='max')
early_stop = EarlyStopping(monitor='val_accuracy', patience=30, restore_best_weights=True)

terminate = TerminateOnNaN()

callbacks = [model_checkpoint, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        working = list(objs)
        if do_shuffle:
            np.random.shuffle(working)
        groups = [working[i:i+batch_size] for i in range(0, len(working), batch_size)]
        
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                img = load_geoimage(filename)
                img = img.astype(np.float32)
                
                if img.ndim == 4:
                    img = img.squeeze(0)
                
                # Extraction des coordonnées et limitation aux bords de l'image
                xmin, ymin, xmax, ymax = obj.bb
                xmin, ymin = max(0, xmin), max(0, ymin)
                xmax, ymax = min(img.shape[1], xmax), min(img.shape[0], ymax)
                
                # Découpage de la zone d'intérêt
                crop_img = img[ymin:ymax, xmin:xmax]
                
                # Exclusion des recadrages vides causant le plantage
                if crop_img.shape[0] == 0 or crop_img.shape[1] == 0:
                    continue
                    
                img_max = crop_img.max()
                if img_max > 1.0:
                    crop_img = crop_img / 255.0 if img_max <= 255.0 else crop_img / 65535.0

                crop_tensor = tf.convert_to_tensor(crop_img)
                
                # Garantie de la dimension des canaux
                if len(crop_tensor.shape) == 2:
                    crop_tensor = tf.expand_dims(crop_tensor, axis=-1)

                img_resized = tf.image.resize(crop_tensor, [96, 96], method='lanczos3')
                images.append(img_resized.numpy())

                label_idx = list(categories.keys())[list(categories.values()).index(obj.category)]
                one_hot = tf.keras.utils.to_categorical(label_idx, num_classes=len(categories))
                labels.append(one_hot)

            # Éviter de retourner un lot vide si toutes les images étaient invalides
            if len(images) > 0:
                yield np.array(images, dtype=np.float32), np.array(labels, dtype=np.float32)

# %%
import math
batch_size = 128
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]

steps_per_epoch = math.ceil(len(objs_train) / batch_size)
valid_steps = math.ceil(len(objs_valid) / batch_size)

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

# labels_train = liste des catégories pour chaque objet dans objs_train
labels_train = [obj.category for (_, obj) in objs_train]
classes = np.array(sorted(set(labels_train)))

weights = compute_class_weight(class_weight='balanced', classes=classes, y=labels_train)
class_weight_dict = dict(zip(classes, weights))

# %%
# Generators
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.optimizers.schedules import CosineDecay
from tensorflow.keras.losses import CategoricalFocalCrossentropy
from tensorflow.keras.optimizers import Nadam

counts_array = np.array([counts[categories[i]] for i in range(len(categories))], dtype=np.float32)
alpha_per_class = 1.0 / np.sqrt(counts_array)
alpha_per_class = alpha_per_class / alpha_per_class.sum()

lr_schedule = CosineDecay(
    initial_learning_rate=0.0005,
    decay_steps=100 * steps_per_epoch
)
optimizer = Nadam(learning_rate=lr_schedule, weight_decay=1e-4)

model.compile(
    optimizer=optimizer,
    loss=CategoricalFocalCrossentropy(alpha=alpha_per_class.tolist(), gamma=1.5),
    metrics=['accuracy']
)

# %%
import math
import numpy as np

print('Training model')

h = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=valid_steps,
    epochs=100,
    callbacks=callbacks,
    verbose=1
)

best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1) + ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.2317 - loss: 0.1117 - val_accuracy: 0.2265 - val_loss: 0.1307
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.3348 - loss: 0.0836 - val_accuracy: 0.3051 - val_loss: 0.1051
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.3820 - loss: 0.0774 - val_accuracy: 0.3222 - val_loss: 0.0962
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.4100 - loss: 0.0733 - val_accuracy: 0.3556 - val_loss: 0.0954
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.4309 - loss: 0.0688 - val_accuracy: 0.3279 - val_loss: 0.0889
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.4488 - loss: 0.0667 - val_accuracy: 0.3400 - val_loss: 0.0878
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.4641 - loss: 0.0638 - val_accuracy: 0.3716 - val_loss: 0.0851
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.4725 - loss: 0.0626 - val_accuracy: 0.3478 - val_loss: 0.1109
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.4703 - loss: 0.0619 - val_accuracy: 0.4346 - val_loss: 0.0713
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.4890 - loss: 0.0594 - val_accuracy: 0.4054 - val_loss: 0.0763
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.5017 - loss: 0.0579 - val_accuracy: 0.4289 - val_loss: 0.0745
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.5128 - loss: 0.0563 - val_accuracy: 0.4235 - val_loss: 0.0807
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - accuracy: 0.5177 - loss: 0.0553 - val_accuracy: 0.4385 - val_loss: 0.0755
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.5341 - loss: 0.0535 - val_accuracy: 0.4218 - val_loss: 0.0800
# Epoch 15/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.5297 - loss: 0.0533 - val_accuracy: 0.4726 - val_loss: 0.0658
# Epoch 16/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.5353 - loss: 0.0520 - val_accuracy: 0.4641 - val_loss: 0.0667
# Epoch 17/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.5501 - loss: 0.0500 - val_accuracy: 0.4666 - val_loss: 0.0701
# Epoch 18/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.5495 - loss: 0.0496 - val_accuracy: 0.4847 - val_loss: 0.0649
# Epoch 19/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.5605 - loss: 0.0489 - val_accuracy: 0.4541 - val_loss: 0.0649
# Epoch 20/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.5674 - loss: 0.0479 - val_accuracy: 0.4591 - val_loss: 0.0689
# Epoch 21/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - accuracy: 0.5604 - loss: 0.0478 - val_accuracy: 0.4982 - val_loss: 0.0651
# Epoch 22/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 187s 1s/step - accuracy: 0.5784 - loss: 0.0461 - val_accuracy: 0.4680 - val_loss: 0.0704
# Epoch 23/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.5817 - loss: 0.0443 - val_accuracy: 0.5092 - val_loss: 0.0632
# Epoch 24/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.5880 - loss: 0.0437 - val_accuracy: 0.4730 - val_loss: 0.0689
# Epoch 25/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.5881 - loss: 0.0439 - val_accuracy: 0.4961 - val_loss: 0.0664
# Epoch 26/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.5911 - loss: 0.0427 - val_accuracy: 0.5274 - val_loss: 0.0600
# Epoch 27/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.6064 - loss: 0.0404 - val_accuracy: 0.5292 - val_loss: 0.0559
# Epoch 28/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.6115 - loss: 0.0397 - val_accuracy: 0.5142 - val_loss: 0.0609
# Epoch 29/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.6143 - loss: 0.0392 - val_accuracy: 0.4683 - val_loss: 0.0676
# Epoch 30/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 197s 2s/step - accuracy: 0.6116 - loss: 0.0394 - val_accuracy: 0.5384 - val_loss: 0.0574
# Epoch 31/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 132s 1s/step - accuracy: 0.6265 - loss: 0.0382 - val_accuracy: 0.5245 - val_loss: 0.0575
# Epoch 32/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.6309 - loss: 0.0376 - val_accuracy: 0.5509 - val_loss: 0.0544
# Epoch 33/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.6486 - loss: 0.0355 - val_accuracy: 0.4932 - val_loss: 0.0623
# Epoch 34/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.6359 - loss: 0.0354 - val_accuracy: 0.5203 - val_loss: 0.0591
# Epoch 35/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.6494 - loss: 0.0341 - val_accuracy: 0.5267 - val_loss: 0.0616
# Epoch 36/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.6654 - loss: 0.0331 - val_accuracy: 0.5277 - val_loss: 0.0588
# Epoch 37/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.6672 - loss: 0.0326 - val_accuracy: 0.5359 - val_loss: 0.0611
# Epoch 38/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.6645 - loss: 0.0318 - val_accuracy: 0.5356 - val_loss: 0.0580
# Epoch 39/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.6818 - loss: 0.0302 - val_accuracy: 0.5199 - val_loss: 0.0585
# Epoch 40/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.6916 - loss: 0.0290 - val_accuracy: 0.5299 - val_loss: 0.0596
# Epoch 41/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.6902 - loss: 0.0288 - val_accuracy: 0.5302 - val_loss: 0.0585
# Epoch 42/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.7041 - loss: 0.0284 - val_accuracy: 0.5331 - val_loss: 0.0597
# Epoch 43/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.7073 - loss: 0.0269 - val_accuracy: 0.5405 - val_loss: 0.0569
# Epoch 44/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.7178 - loss: 0.0258 - val_accuracy: 0.5651 - val_loss: 0.0555
# Epoch 45/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.7294 - loss: 0.0245 - val_accuracy: 0.5690 - val_loss: 0.0558
# Epoch 46/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.7226 - loss: 0.0248 - val_accuracy: 0.5676 - val_loss: 0.0564
# Epoch 47/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.7370 - loss: 0.0227 - val_accuracy: 0.5530 - val_loss: 0.0549
# Epoch 48/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.7376 - loss: 0.0234 - val_accuracy: 0.5679 - val_loss: 0.0542
# Epoch 49/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.7533 - loss: 0.0213 - val_accuracy: 0.5672 - val_loss: 0.0548
# Epoch 50/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.7597 - loss: 0.0206 - val_accuracy: 0.5576 - val_loss: 0.0568
# Epoch 51/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.7732 - loss: 0.0196 - val_accuracy: 0.5775 - val_loss: 0.0546
# Epoch 52/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.7755 - loss: 0.0192 - val_accuracy: 0.5786 - val_loss: 0.0555
# Epoch 53/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.7816 - loss: 0.0186 - val_accuracy: 0.5615 - val_loss: 0.0585
# Epoch 54/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.7886 - loss: 0.0178 - val_accuracy: 0.5857 - val_loss: 0.0543
# Epoch 55/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.7974 - loss: 0.0168 - val_accuracy: 0.5669 - val_loss: 0.0560
# Epoch 56/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.8008 - loss: 0.0166 - val_accuracy: 0.5893 - val_loss: 0.0551
# Epoch 57/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 186s 1s/step - accuracy: 0.8083 - loss: 0.0157 - val_accuracy: 0.5743 - val_loss: 0.0550
# Epoch 58/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.8167 - loss: 0.0147 - val_accuracy: 0.5910 - val_loss: 0.0539
# Epoch 59/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.8286 - loss: 0.0140 - val_accuracy: 0.5878 - val_loss: 0.0552
# Epoch 60/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.8321 - loss: 0.0136 - val_accuracy: 0.5793 - val_loss: 0.0576
# Epoch 61/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.8403 - loss: 0.0129 - val_accuracy: 0.5935 - val_loss: 0.0577
# Epoch 62/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.8519 - loss: 0.0118 - val_accuracy: 0.5871 - val_loss: 0.0558
# Epoch 63/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.8587 - loss: 0.0114 - val_accuracy: 0.5914 - val_loss: 0.0550
# Epoch 64/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.8623 - loss: 0.0109 - val_accuracy: 0.5953 - val_loss: 0.0572
# Epoch 65/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.8627 - loss: 0.0112 - val_accuracy: 0.5996 - val_loss: 0.0557
# Epoch 66/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.8668 - loss: 0.0102 - val_accuracy: 0.5985 - val_loss: 0.0575
# Epoch 67/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.8738 - loss: 0.0100 - val_accuracy: 0.6017 - val_loss: 0.0569
# Epoch 68/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.8736 - loss: 0.0095 - val_accuracy: 0.5900 - val_loss: 0.0567
# Epoch 69/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.8856 - loss: 0.0089 - val_accuracy: 0.5989 - val_loss: 0.0574
# Epoch 70/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - accuracy: 0.8944 - loss: 0.0085 - val_accuracy: 0.5996 - val_loss: 0.0560
# Epoch 71/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.8962 - loss: 0.0083 - val_accuracy: 0.6120 - val_loss: 0.0575
# Epoch 72/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.8972 - loss: 0.0079 - val_accuracy: 0.6046 - val_loss: 0.0594
# Epoch 73/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.9024 - loss: 0.0078 - val_accuracy: 0.6078 - val_loss: 0.0580
# Epoch 74/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9033 - loss: 0.0074 - val_accuracy: 0.6046 - val_loss: 0.0589
# Epoch 75/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.9136 - loss: 0.0069 - val_accuracy: 0.5957 - val_loss: 0.0582
# Epoch 76/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 181s 1s/step - accuracy: 0.9113 - loss: 0.0068 - val_accuracy: 0.6003 - val_loss: 0.0591
# Epoch 77/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.9197 - loss: 0.0065 - val_accuracy: 0.6049 - val_loss: 0.0589
# Epoch 78/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9172 - loss: 0.0065 - val_accuracy: 0.6067 - val_loss: 0.0580
# Epoch 79/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.9161 - loss: 0.0064 - val_accuracy: 0.6035 - val_loss: 0.0583
# Epoch 80/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 184s 1s/step - accuracy: 0.9209 - loss: 0.0061 - val_accuracy: 0.6063 - val_loss: 0.0598
# Epoch 81/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.9253 - loss: 0.0058 - val_accuracy: 0.6102 - val_loss: 0.0582
# Epoch 82/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - accuracy: 0.9272 - loss: 0.0058 - val_accuracy: 0.6092 - val_loss: 0.0590
# Epoch 83/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 205s 2s/step - accuracy: 0.9288 - loss: 0.0054 - val_accuracy: 0.6060 - val_loss: 0.0590
# Epoch 84/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.9334 - loss: 0.0052 - val_accuracy: 0.6085 - val_loss: 0.0587
# Epoch 85/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.9295 - loss: 0.0054 - val_accuracy: 0.6099 - val_loss: 0.0588
# Epoch 86/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - accuracy: 0.9321 - loss: 0.0052 - val_accuracy: 0.6152 - val_loss: 0.0590
# Epoch 87/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9354 - loss: 0.0052 - val_accuracy: 0.6138 - val_loss: 0.0589
# Epoch 88/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.9381 - loss: 0.0050 - val_accuracy: 0.6131 - val_loss: 0.0596
# Epoch 89/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.9391 - loss: 0.0048 - val_accuracy: 0.6127 - val_loss: 0.0592
# Epoch 90/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9411 - loss: 0.0048 - val_accuracy: 0.6206 - val_loss: 0.0591
# Epoch 91/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9419 - loss: 0.0047 - val_accuracy: 0.6152 - val_loss: 0.0591
# Epoch 92/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9398 - loss: 0.0049 - val_accuracy: 0.6149 - val_loss: 0.0593
# Epoch 93/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9442 - loss: 0.0045 - val_accuracy: 0.6177 - val_loss: 0.0592
# Epoch 94/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 191s 2s/step - accuracy: 0.9449 - loss: 0.0044 - val_accuracy: 0.6195 - val_loss: 0.0593
# Epoch 95/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 180s 1s/step - accuracy: 0.9426 - loss: 0.0047 - val_accuracy: 0.6198 - val_loss: 0.0591
# Epoch 96/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.9400 - loss: 0.0047 - val_accuracy: 0.6174 - val_loss: 0.0592
# Epoch 97/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.9434 - loss: 0.0047 - val_accuracy: 0.6184 - val_loss: 0.0591
# Epoch 98/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.9427 - loss: 0.0046 - val_accuracy: 0.6195 - val_loss: 0.0591
# Epoch 99/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.9453 - loss: 0.0044 - val_accuracy: 0.6191 - val_loss: 0.0591
# Epoch 100/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9430 - loss: 0.0045 - val_accuracy: 0.6188 - val_loss: 0.0592
# Best validation model: epoch 90 - val_accuracy 0.6205547451972961

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np
import tensorflow as tf

model.load_weights('model.keras')
y_true, y_pred = [], []
all_images = []
temp_true_labels = []

for ann in anns_valid:
    image_raw = load_geoimage(ann.filename)
    img = image_raw.astype(np.float32)
    if img.ndim == 4:
        img = img.squeeze(0)

    for obj_pred in ann.objects:
        # Extraction stricte de la boîte englobante
        xmin, ymin, xmax, ymax = obj_pred.bb
        xmin, ymin = max(0, xmin), max(0, ymin)
        xmax, ymax = min(img.shape[1], xmax), min(img.shape[0], ymax)
        
        crop_img = img[ymin:ymax, xmin:xmax]
        
        # Ignorer les recadrages invalides
        if crop_img.shape[0] == 0 or crop_img.shape[1] == 0:
            continue

        img_max = crop_img.max()
        if img_max > 1.0:
            crop_img = crop_img / 255.0 if img_max <= 255.0 else crop_img / 65535.0

        crop_tensor = tf.convert_to_tensor(crop_img)
        if len(crop_tensor.shape) == 2:
            crop_tensor = tf.expand_dims(crop_tensor, axis=-1)

        img_resized = tf.image.resize(crop_tensor, [96, 96], method='lanczos3')
        
        all_images.append(img_resized.numpy())
        temp_true_labels.append(obj_pred.category)

if all_images:
    X_valid = np.array(all_images)
    print(f"Lancement de la prédiction sur {len(X_valid)} objets...")
    all_predictions = model.predict(X_valid, batch_size=64, verbose=1)
    category_names = list(categories.values())
    for i in range(len(all_predictions)):
        pred_category = category_names[np.argmax(all_predictions[i])]
        y_true.append(temp_true_labels[i])
        y_pred.append(pred_category)
# Out:
# Lancement de la prédiction sur 2812 objets...
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 62.055%
# Mean Recall: 64.230%
# Mean Precision: 66.044%
# > Cargo plane: Recall: 83.158% Precision: 86.813% Specificity: 99.558% Dice: 84.946%
# > Small car: Recall: 76.353% Precision: 68.036% Specificity: 92.261% Dice: 71.955%
# > Bus: Recall: 51.698% Precision: 47.902% Specificity: 94.150% Dice: 49.728%
# > Truck: Recall: 27.108% Precision: 31.469% Specificity: 92.097% Dice: 29.126%
# > Motorboat: Recall: 70.000% Precision: 68.293% Specificity: 98.039% Dice: 69.136%
# > Fishing vessel: Recall: 60.377% Precision: 66.667% Specificity: 98.817% Dice: 63.366%
# > Dump truck: Recall: 50.270% Precision: 53.757% Specificity: 96.955% Dice: 51.955%
# > Excavator: Recall: 73.729% Precision: 66.923% Specificity: 98.404% Dice: 70.161%
# > Building: Recall: 68.460% Precision: 69.101% Specificity: 92.741% Dice: 68.779%
# > Helipad: Recall: 64.706% Precision: 84.615% Specificity: 99.928% Dice: 73.333%
# > Storage tank: Recall: 65.455% Precision: 72.362% Specificity: 97.878% Dice: 68.735%
# > Shipping container: Recall: 60.699% Precision: 59.657% Specificity: 96.361% Dice: 60.173%
# > Pylon: Recall: 82.979% Precision: 82.979% Specificity: 99.711% Dice: 82.979%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
root_dir = './xview_recognition/'
test_dir = os.path.join(root_dir, 'xview_test')
for (dirpath, dirnames, filenames) in os.walk(test_dir):
    for filename in filenames:
        rel_dir = os.path.relpath(dirpath, root_dir)
        clean_filename = os.path.join(rel_dir, filename)
        image = GenericImage(clean_filename)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = os.path.basename(dirpath)
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np
import tensorflow as tf

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
all_test_images = []
metadata = []
ann_id = 0

print("Préparation des images de test...")
for idx, ann in enumerate(anns):
    predictions_data["images"][idx] = {
        "image_id": ann.filename.split('/')[-1],
        "filename": ann.filename,
        "width": int(ann.tile[2]),
        "height": int(ann.tile[3])
    }

    image_raw = load_geoimage(ann.filename)
    img = image_raw.astype(np.float32)
    if img.ndim == 4:
        img = img.squeeze(0)

    for obj_pred in ann.objects:
        # Extraction stricte de la boîte englobante
        xmin, ymin, xmax, ymax = obj_pred.bb
        xmin, ymin = max(0, xmin), max(0, ymin)
        xmax, ymax = min(img.shape[1], xmax), min(img.shape[0], ymax)
        
        crop_img = img[ymin:ymax, xmin:xmax]
        
        # Ignorer les recadrages invalides
        if crop_img.shape[0] == 0 or crop_img.shape[1] == 0:
            continue

        img_max = crop_img.max()
        if img_max > 1.0:
            crop_img = crop_img / 255.0 if img_max <= 255.0 else crop_img / 65535.0

        crop_tensor = tf.convert_to_tensor(crop_img)
        if len(crop_tensor.shape) == 2:
            crop_tensor = tf.expand_dims(crop_tensor, axis=-1)

        img_resized = tf.image.resize(crop_tensor, [96, 96], method='lanczos3')
        
        all_test_images.append(img_resized.numpy())
        metadata.append({
            "image_id": ann.filename.split('/')[-1],
            "bbox": [int(x) for x in obj_pred.bb]
        })

if all_test_images:
    X_test = np.array(all_test_images)
    print(f"Prédiction en cours sur {len(X_test)} détections...")
    all_preds = model.predict(X_test, batch_size=128, verbose=1)
    category_names = list(categories.values())
    for i, pred in enumerate(all_preds):
        predictions_data["annotations"][ann_id] = {
            "image_id": metadata[i]["image_id"],
            "category_id": category_names[np.argmax(pred)],
            "bbox": metadata[i]["bbox"]
        }
        ann_id += 1
print("Test terminé.")
# Out:
# Préparation des images de test...
# Prédiction en cours sur 2365 détections...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step
# Test terminé.

# %%
import json
with open('prediction.json', 'w') as f:
    json.dump(predictions_data, f)
