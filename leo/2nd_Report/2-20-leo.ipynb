# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1:
# - Alumno 2:
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import requests
import zipfile

url = 'https://drive.upm.es/s/2DDPE2zHw5dbM3G/download'
zip_name = 'dataset.zip'

r = requests.get(url, stream=True)
with open(zip_name, 'wb') as f:
    for chunk in r.iter_content(chunk_size=1024):
        f.write(chunk)

if os.path.getsize(zip_name) < 10000:
    print(f"ERREUR : Le fichier {zip_name} est trop petit. Le lien est invalide ou nécessite une connexion.")
else:
    with zipfile.ZipFile(zip_name, 'r') as z:
        z.extractall(".")

    target_file = 'xview_ann_train.json'
    found_path = None

    for root, dirs, files in os.walk("."):
        if target_file in files:
            found_path = os.path.join(root, target_file)
            break

    if found_path:
        print(f"SUCCÈS : Fichier trouvé à : {found_path}")

        import json
        json_file = found_path

        with open(json_file) as ifs:
            json_data = json.load(ifs)
        print("Base de données chargée avec succès !")

    else:
        print(f"ERREUR : {target_file} reste introuvable après extraction.")
# Out:
# SUCCÈS : Fichier trouvé à : ./xview_recognition/xview_ann_train.json
# Base de données chargée avec succès !

# %%
import tensorflow as tf

# Vérifie la présence de processeurs graphiques
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    try:
        # Configuration pour ne pas allouer toute la mémoire d'un coup
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"GPU activé : {len(gpus)} processeur(s) détecté(s)")
    except RuntimeError as e:
        print(e)
else:
    print("GPU non détecté. Activez l'accélérateur dans les réglages du notebook.")
# Out:
# 2026-02-24 21:41:58.296206: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771969318.558777      17 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771969318.637744      17 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771969319.246224      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771969319.246289      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771969319.246292      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771969319.246295      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# GPU non détecté. Activez l'accélérateur dans les réglages du notebook.
# 2026-02-24 21:42:31.262636: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.1.4)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.1)

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open('./xview_recognition/'+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
json_file = './xview_recognition/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
labels = [img.objects[0].category for img in anns]
# Out:
# {'Cargo plane': 635, 'Small car': 3324, 'Bus': 1768, 'Truck': 2210, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 3594, 'Helipad': 111, 'Storage tank': 1469, 'Shipping container': 1523, 'Pylon': 312}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.15, random_state=42, shuffle=True, stratify=labels)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 15934
# Number of validation images: 2812

# %%
from tensorflow.keras.layers import Dense, BatchNormalization, Activation, Dropout, Flatten, Input, Add
from tensorflow.keras.models import Model
import tensorflow as tf

def dense_residual_block(x, units, dropout_rate=0.2):
    # projection du raccourci si la taille change
    shortcut = Dense(units, use_bias=False)(x)
    shortcut = BatchNormalization()(shortcut)

    out = Dense(units, kernel_initializer='he_normal', use_bias=False)(x)
    out = BatchNormalization()(out)
    out = Activation('gelu')(out)
    out = Dropout(dropout_rate)(out)

    out = Dense(units, kernel_initializer='he_normal', use_bias=False)(out)
    out = BatchNormalization()(out)

    out = Add()([out, shortcut])
    out = Activation('gelu')(out)
    return out

inputs = Input(shape=(96, 96, 3))
x = tf.keras.layers.RandomFlip("horizontal_and_vertical")(inputs)
x = tf.keras.layers.RandomRotation(0.25)(x)
x = Flatten()(x)

# Goulot d’étranglement global
x = Dense(512, kernel_initializer='he_normal', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)
x = Dropout(0.3)(x)

# Bloc large
x = dense_residual_block(x, 512, dropout_rate=0.3)

# Bloc moyen
x = dense_residual_block(x, 256, dropout_rate=0.3)

# Petit bloc final
x = dense_residual_block(x, 128, dropout_rate=0.3)

# Dernier shrink + sortie
x = Dense(128, kernel_initializer='he_normal', use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('gelu')(x)
x = Dropout(0.4)(x)

outputs = Dense(len(categories), activation='softmax')(x)
model = Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 96, 96, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_flip         │ (None, 96, 96, 3) │          0 │ input_layer[0][0] │
# │ (RandomFlip)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ random_rotation     │ (None, 96, 96, 3) │          0 │ random_flip[0][0] │
# │ (RandomRotation)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 27648)     │          0 │ random_rotation[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1024)      │ 28,311,552 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 1024)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1024)      │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1024)      │  1,048,576 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1024)      │ 28,311,552 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1024)      │      4,096 │ dense[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1024)      │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1024)      │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1024)      │  1,048,576 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 1024)      │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 1024)      │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1024)      │  1,048,576 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1024)      │  1,048,576 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_5[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1024)      │      4,096 │ dense_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1024)      │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 1024)      │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 512)       │    524,288 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_7[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 512)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 512)       │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 512)       │    262,144 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 512)       │    524,288 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_8[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_6[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 512)       │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 512)       │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 256)       │    131,072 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_10[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 256)       │     65,536 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 256)       │    131,072 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_11[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_9[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 256)       │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 256)       │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 13)        │      3,341 │ activation_7[0][… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 62,492,941 (238.39 MB)
#  Trainable params: 62,476,045 (238.33 MB)
#  Non-trainable params: 16,896 (66.00 KB)

# %%
#from tensorflow.keras.optimizers import Adam
#
## Learning rate is changed to 0.001
#opt = Adam(learning_rate=lr_schedule, beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
#model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

model_checkpoint = ModelCheckpoint('model.keras', monitor='val_accuracy', save_best_only=True, mode='max')
early_stop = EarlyStopping(monitor='val_accuracy', patience=30, restore_best_weights=True)

terminate = TerminateOnNaN()

callbacks = [
    ModelCheckpoint('model.keras', monitor='val_accuracy', save_best_only=True, mode='max'),
    EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True),
    TerminateOnNaN()
]

# %%
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        working = list(objs)
        if do_shuffle:
            np.random.shuffle(working)
        groups = [working[i:i+batch_size] for i in range(0, len(working), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                img = load_geoimage(filename)
                img = img.astype(np.float32)
                if img.ndim == 4:
                    img = img.squeeze(0)
                img_max = img.max()
                if img_max > 1.0:
                    img = img / 255.0 if img_max <= 255.0 else img / 65535.0

                # CROP BBOX avec marge de contexte 15%
                x1, y1, x2, y2 = int(obj.bb[0]), int(obj.bb[1]), int(obj.bb[2]), int(obj.bb[3])
                h_img, w_img = img.shape[0], img.shape[1]
                bw = max(1, x2 - x1)
                bh = max(1, y2 - y1)
                pad_x = max(4, int(bw * 0.15))
                pad_y = max(4, int(bh * 0.15))
                x1c = max(0, x1 - pad_x)
                y1c = max(0, y1 - pad_y)
                x2c = min(w_img, x2 + pad_x)
                y2c = min(h_img, y2 + pad_y)
                crop = img[y1c:y2c, x1c:x2c, :]
                if crop.shape[0] == 0 or crop.shape[1] == 0:
                    crop = img

                img_resized = tf.image.resize(tf.convert_to_tensor(crop), [96, 96], method='lanczos3')
                images.append(img_resized.numpy())

                label_idx = list(categories.keys())[list(categories.values()).index(obj.category)]
                one_hot = tf.keras.utils.to_categorical(label_idx, num_classes=len(categories))
                labels.append(one_hot)

            yield np.array(images, dtype=np.float32), np.array(labels, dtype=np.float32)

# %%
import math
batch_size = 128
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]

steps_per_epoch = math.ceil(len(objs_train) / batch_size)
valid_steps     = math.ceil(len(objs_valid) / batch_size)

train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight

labels_train = [obj.category for (_, obj) in objs_train]
classes = np.array(sorted(set(labels_train)))
weights = compute_class_weight(class_weight='balanced', classes=classes, y=labels_train)
class_weight_dict = dict(zip(classes, weights))

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.optimizers.schedules import CosineDecay
from tensorflow.keras.losses import CategoricalFocalCrossentropy
from tensorflow.keras.optimizers import Nadam


counts_array = np.array([counts[categories[i]] for i in range(len(categories))], dtype=np.float32)
alpha_per_class = 1.0 / np.sqrt(counts_array)
alpha_per_class = alpha_per_class / alpha_per_class.sum()

lr_schedule = CosineDecay(
    initial_learning_rate=0.0002,
    decay_steps=100 * steps_per_epoch
)
optimizer = Nadam(learning_rate=lr_schedule, weight_decay=1e-4)

model.compile(
    optimizer=optimizer,
    loss=CategoricalFocalCrossentropy(alpha=alpha_per_class.tolist(), gamma=1.5),
    metrics=['accuracy']
)

# %%
import math
import numpy as np

print('Training model')

h = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=valid_steps,
    epochs=100,
    callbacks=callbacks,
    #class_weight=class_weight_dict,
    verbose=1
)

best_idx = int(np.argmax(h.history['val_accuracy']))
best_value = np.max(h.history['val_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1) + ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 297s 2s/step - accuracy: 0.2183 - loss: 0.1126 - val_accuracy: 0.2461 - val_loss: 0.1167
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 285s 2s/step - accuracy: 0.3387 - loss: 0.0829 - val_accuracy: 0.2877 - val_loss: 0.1047
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - accuracy: 0.3820 - loss: 0.0761 - val_accuracy: 0.3090 - val_loss: 0.1075
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 291s 2s/step - accuracy: 0.4139 - loss: 0.0715 - val_accuracy: 0.3674 - val_loss: 0.0841
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 283s 2s/step - accuracy: 0.4256 - loss: 0.0703 - val_accuracy: 0.3723 - val_loss: 0.0869
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 0.4519 - loss: 0.0662 - val_accuracy: 0.3407 - val_loss: 0.0986
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 284s 2s/step - accuracy: 0.4583 - loss: 0.0646 - val_accuracy: 0.3915 - val_loss: 0.0872
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 303s 2s/step - accuracy: 0.4742 - loss: 0.0629 - val_accuracy: 0.3684 - val_loss: 0.0920
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 0.4777 - loss: 0.0608 - val_accuracy: 0.3983 - val_loss: 0.0849
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.5029 - loss: 0.0587 - val_accuracy: 0.4189 - val_loss: 0.0740
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 276s 2s/step - accuracy: 0.5045 - loss: 0.0575 - val_accuracy: 0.4232 - val_loss: 0.0711
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 293s 2s/step - accuracy: 0.5143 - loss: 0.0563 - val_accuracy: 0.4413 - val_loss: 0.0705
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 315s 3s/step - accuracy: 0.5157 - loss: 0.0558 - val_accuracy: 0.4744 - val_loss: 0.0627
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.5359 - loss: 0.0531 - val_accuracy: 0.4147 - val_loss: 0.0827
# Epoch 15/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 284s 2s/step - accuracy: 0.5297 - loss: 0.0534 - val_accuracy: 0.4858 - val_loss: 0.0665
# Epoch 16/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 306s 2s/step - accuracy: 0.5482 - loss: 0.0508 - val_accuracy: 0.3994 - val_loss: 0.0929
# Epoch 17/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 0.5392 - loss: 0.0508 - val_accuracy: 0.4716 - val_loss: 0.0661
# Epoch 18/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.5504 - loss: 0.0493 - val_accuracy: 0.4666 - val_loss: 0.0658
# Epoch 19/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 239s 2s/step - accuracy: 0.5566 - loss: 0.0488 - val_accuracy: 0.4708 - val_loss: 0.0676
# Epoch 20/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.5555 - loss: 0.0482 - val_accuracy: 0.4801 - val_loss: 0.0644
# Epoch 21/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 324s 3s/step - accuracy: 0.5692 - loss: 0.0465 - val_accuracy: 0.4769 - val_loss: 0.0659
# Epoch 22/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 283s 2s/step - accuracy: 0.5746 - loss: 0.0453 - val_accuracy: 0.4932 - val_loss: 0.0632
# Epoch 23/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 321s 3s/step - accuracy: 0.5758 - loss: 0.0448 - val_accuracy: 0.4954 - val_loss: 0.0665
# Epoch 24/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.5900 - loss: 0.0432 - val_accuracy: 0.4872 - val_loss: 0.0713
# Epoch 25/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 311s 2s/step - accuracy: 0.5829 - loss: 0.0437 - val_accuracy: 0.5060 - val_loss: 0.0605
# Epoch 26/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 282s 2s/step - accuracy: 0.6022 - loss: 0.0425 - val_accuracy: 0.4964 - val_loss: 0.0651
# Epoch 27/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - accuracy: 0.6022 - loss: 0.0413 - val_accuracy: 0.4812 - val_loss: 0.0611
# Epoch 28/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.5963 - loss: 0.0415 - val_accuracy: 0.4897 - val_loss: 0.0694
# Epoch 29/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 269s 2s/step - accuracy: 0.6160 - loss: 0.0391 - val_accuracy: 0.5501 - val_loss: 0.0556
# Epoch 30/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - accuracy: 0.6224 - loss: 0.0383 - val_accuracy: 0.5188 - val_loss: 0.0569
# Epoch 31/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 252s 2s/step - accuracy: 0.6218 - loss: 0.0374 - val_accuracy: 0.5263 - val_loss: 0.0573
# Epoch 32/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.6274 - loss: 0.0376 - val_accuracy: 0.5370 - val_loss: 0.0553
# Epoch 33/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 237s 2s/step - accuracy: 0.6312 - loss: 0.0367 - val_accuracy: 0.4787 - val_loss: 0.0724
# Epoch 34/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.6460 - loss: 0.0349 - val_accuracy: 0.5345 - val_loss: 0.0550
# Epoch 35/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.6497 - loss: 0.0351 - val_accuracy: 0.4836 - val_loss: 0.0690
# Epoch 36/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.6562 - loss: 0.0341 - val_accuracy: 0.5270 - val_loss: 0.0609
# Epoch 37/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 277s 2s/step - accuracy: 0.6666 - loss: 0.0321 - val_accuracy: 0.5349 - val_loss: 0.0573
# Epoch 38/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.6724 - loss: 0.0313 - val_accuracy: 0.5011 - val_loss: 0.0647
# Epoch 39/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.6779 - loss: 0.0304 - val_accuracy: 0.5238 - val_loss: 0.0629
# Epoch 40/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 282s 2s/step - accuracy: 0.6845 - loss: 0.0295 - val_accuracy: 0.5590 - val_loss: 0.0519
# Epoch 41/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.6955 - loss: 0.0278 - val_accuracy: 0.5242 - val_loss: 0.0597
# Epoch 42/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 0.7002 - loss: 0.0278 - val_accuracy: 0.5541 - val_loss: 0.0521
# Epoch 43/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 249s 2s/step - accuracy: 0.7131 - loss: 0.0260 - val_accuracy: 0.5324 - val_loss: 0.0592
# Epoch 44/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.7087 - loss: 0.0263 - val_accuracy: 0.5789 - val_loss: 0.0533
# Epoch 45/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 301s 2s/step - accuracy: 0.7294 - loss: 0.0242 - val_accuracy: 0.5530 - val_loss: 0.0564
# Epoch 46/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.7329 - loss: 0.0238 - val_accuracy: 0.5612 - val_loss: 0.0527
# Epoch 47/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - accuracy: 0.7321 - loss: 0.0232 - val_accuracy: 0.5814 - val_loss: 0.0552
# Epoch 48/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.7514 - loss: 0.0217 - val_accuracy: 0.5711 - val_loss: 0.0550
# Epoch 49/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.7595 - loss: 0.0211 - val_accuracy: 0.5377 - val_loss: 0.0582
# Epoch 50/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - accuracy: 0.7579 - loss: 0.0209 - val_accuracy: 0.5637 - val_loss: 0.0549
# Epoch 51/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.7710 - loss: 0.0195 - val_accuracy: 0.5562 - val_loss: 0.0568
# Epoch 52/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.7721 - loss: 0.0190 - val_accuracy: 0.5715 - val_loss: 0.0569
# Epoch 53/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.7890 - loss: 0.0181 - val_accuracy: 0.5583 - val_loss: 0.0583
# Epoch 54/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 257s 2s/step - accuracy: 0.7854 - loss: 0.0181 - val_accuracy: 0.5722 - val_loss: 0.0570
# Epoch 55/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 302s 2s/step - accuracy: 0.8022 - loss: 0.0164 - val_accuracy: 0.5622 - val_loss: 0.0568
# Epoch 56/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.8081 - loss: 0.0155 - val_accuracy: 0.5754 - val_loss: 0.0580
# Epoch 57/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 300s 2s/step - accuracy: 0.8195 - loss: 0.0150 - val_accuracy: 0.5743 - val_loss: 0.0562
# Epoch 58/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 291s 2s/step - accuracy: 0.8232 - loss: 0.0140 - val_accuracy: 0.5818 - val_loss: 0.0555
# Epoch 59/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 313s 3s/step - accuracy: 0.8262 - loss: 0.0138 - val_accuracy: 0.5775 - val_loss: 0.0579
# Epoch 60/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 273s 2s/step - accuracy: 0.8335 - loss: 0.0135 - val_accuracy: 0.5622 - val_loss: 0.0613
# Epoch 61/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.8408 - loss: 0.0130 - val_accuracy: 0.5757 - val_loss: 0.0573
# Epoch 62/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - accuracy: 0.8531 - loss: 0.0118 - val_accuracy: 0.5765 - val_loss: 0.0567
# Epoch 63/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 264s 2s/step - accuracy: 0.8539 - loss: 0.0115 - val_accuracy: 0.5800 - val_loss: 0.0584
# Epoch 64/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.8625 - loss: 0.0110 - val_accuracy: 0.5846 - val_loss: 0.0573
# Epoch 65/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.8649 - loss: 0.0107 - val_accuracy: 0.5797 - val_loss: 0.0594
# Epoch 66/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 248s 2s/step - accuracy: 0.8702 - loss: 0.0105 - val_accuracy: 0.5903 - val_loss: 0.0585
# Epoch 67/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 259s 2s/step - accuracy: 0.8729 - loss: 0.0101 - val_accuracy: 0.5871 - val_loss: 0.0575
# Epoch 68/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.8773 - loss: 0.0095 - val_accuracy: 0.5857 - val_loss: 0.0574
# Epoch 69/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 265s 2s/step - accuracy: 0.8866 - loss: 0.0087 - val_accuracy: 0.5992 - val_loss: 0.0582
# Epoch 70/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 267s 2s/step - accuracy: 0.8869 - loss: 0.0086 - val_accuracy: 0.6010 - val_loss: 0.0576
# Epoch 71/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 237s 2s/step - accuracy: 0.8962 - loss: 0.0081 - val_accuracy: 0.5960 - val_loss: 0.0577
# Epoch 72/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.9001 - loss: 0.0080 - val_accuracy: 0.5921 - val_loss: 0.0593
# Epoch 73/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.9022 - loss: 0.0078 - val_accuracy: 0.6010 - val_loss: 0.0580
# Epoch 74/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 252s 2s/step - accuracy: 0.9084 - loss: 0.0073 - val_accuracy: 0.5900 - val_loss: 0.0599
# Epoch 75/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 319s 3s/step - accuracy: 0.9169 - loss: 0.0067 - val_accuracy: 0.5978 - val_loss: 0.0595
# Epoch 76/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.9132 - loss: 0.0067 - val_accuracy: 0.6028 - val_loss: 0.0584
# Epoch 77/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 257s 2s/step - accuracy: 0.9165 - loss: 0.0065 - val_accuracy: 0.5992 - val_loss: 0.0604
# Epoch 78/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 224s 2s/step - accuracy: 0.9202 - loss: 0.0064 - val_accuracy: 0.5978 - val_loss: 0.0601
# Epoch 79/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 267s 2s/step - accuracy: 0.9180 - loss: 0.0063 - val_accuracy: 0.5942 - val_loss: 0.0597
# Epoch 80/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.9228 - loss: 0.0059 - val_accuracy: 0.6021 - val_loss: 0.0590
# Epoch 81/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.9266 - loss: 0.0056 - val_accuracy: 0.6003 - val_loss: 0.0600
# Epoch 82/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.9271 - loss: 0.0058 - val_accuracy: 0.6024 - val_loss: 0.0598
# Epoch 83/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9299 - loss: 0.0054 - val_accuracy: 0.6085 - val_loss: 0.0593
# Epoch 84/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 284s 2s/step - accuracy: 0.9272 - loss: 0.0059 - val_accuracy: 0.6003 - val_loss: 0.0596
# Epoch 85/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.9372 - loss: 0.0049 - val_accuracy: 0.6003 - val_loss: 0.0602
# Epoch 86/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.9355 - loss: 0.0053 - val_accuracy: 0.6081 - val_loss: 0.0596
# Epoch 87/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 289s 2s/step - accuracy: 0.9354 - loss: 0.0051 - val_accuracy: 0.5982 - val_loss: 0.0605
# Epoch 88/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 287s 2s/step - accuracy: 0.9389 - loss: 0.0049 - val_accuracy: 0.6035 - val_loss: 0.0599
# Epoch 89/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.9339 - loss: 0.0049 - val_accuracy: 0.6070 - val_loss: 0.0597
# Epoch 90/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.9387 - loss: 0.0048 - val_accuracy: 0.6110 - val_loss: 0.0601
# Epoch 91/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9364 - loss: 0.0049 - val_accuracy: 0.6078 - val_loss: 0.0600
# Epoch 92/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.9413 - loss: 0.0047 - val_accuracy: 0.6088 - val_loss: 0.0602
# Epoch 93/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 227s 2s/step - accuracy: 0.9436 - loss: 0.0045 - val_accuracy: 0.6085 - val_loss: 0.0601
# Epoch 94/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.9398 - loss: 0.0048 - val_accuracy: 0.6102 - val_loss: 0.0602
# Epoch 95/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.9477 - loss: 0.0043 - val_accuracy: 0.6110 - val_loss: 0.0601
# Epoch 96/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 239s 2s/step - accuracy: 0.9434 - loss: 0.0047 - val_accuracy: 0.6078 - val_loss: 0.0602
# Epoch 97/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 239s 2s/step - accuracy: 0.9467 - loss: 0.0043 - val_accuracy: 0.6063 - val_loss: 0.0603
# Epoch 98/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 252s 2s/step - accuracy: 0.9428 - loss: 0.0047 - val_accuracy: 0.6092 - val_loss: 0.0603
# Epoch 99/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.9431 - loss: 0.0048 - val_accuracy: 0.6088 - val_loss: 0.0602
# Epoch 100/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 247s 2s/step - accuracy: 0.9486 - loss: 0.0043 - val_accuracy: 0.6070 - val_loss: 0.0602
# Best validation model: epoch 90 - val_accuracy 0.6109530329704285

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# %%
import numpy as np
import tensorflow as tf

model.load_weights('model.keras')
y_true, y_pred = [], []
all_images, temp_true_labels = [], []

for ann in anns_valid:
    image_raw = load_geoimage(ann.filename)
    img = image_raw.astype(np.float32)
    if img.ndim == 4:
        img = img.squeeze(0)
    img_max = img.max()
    if img_max > 1.0:
        img = img / 255.0 if img_max <= 255.0 else img / 65535.0

    for obj_pred in ann.objects:
        x1, y1, x2, y2 = int(obj_pred.bb[0]), int(obj_pred.bb[1]), int(obj_pred.bb[2]), int(obj_pred.bb[3])
        h_img, w_img = img.shape[0], img.shape[1]
        bw = max(1, x2 - x1)
        bh = max(1, y2 - y1)
        pad_x = max(4, int(bw * 0.15))
        pad_y = max(4, int(bh * 0.15))
        x1c = max(0, x1 - pad_x)
        y1c = max(0, y1 - pad_y)
        x2c = min(w_img, x2 + pad_x)
        y2c = min(h_img, y2 + pad_y)
        crop = img[y1c:y2c, x1c:x2c, :]
        if crop.shape[0] == 0 or crop.shape[1] == 0:
            crop = img

        img_resized = tf.image.resize(tf.convert_to_tensor(crop), [96, 96], method='lanczos3')
        all_images.append(img_resized.numpy())
        temp_true_labels.append(obj_pred.category)

if all_images:
    X_valid = np.array(all_images)
    print(f'Lancement de la prédiction sur {len(X_valid)} objets...')
    all_predictions = model.predict(X_valid, batch_size=64, verbose=1)
    category_names = list(categories.values())
    for i in range(len(all_predictions)):
        y_pred.append(category_names[np.argmax(all_predictions[i])])
        y_true.append(temp_true_labels[i])
# Out:
# Lancement de la prédiction sur 2812 objets...
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
# Out:
# Mean Accuracy: 61.095%
# Mean Recall: 62.836%
# Mean Precision: 64.377%
# > Cargo plane: Recall: 81.053% Precision: 87.500% Specificity: 99.595% Dice: 84.153%
# > Small car: Recall: 74.549% Precision: 70.321% Specificity: 93.212% Dice: 72.374%
# > Bus: Recall: 50.943% Precision: 46.552% Specificity: 93.914% Dice: 48.649%
# > Truck: Recall: 25.602% Precision: 30.909% Specificity: 92.339% Dice: 28.007%
# > Motorboat: Recall: 63.125% Precision: 59.064% Specificity: 97.360% Dice: 61.027%
# > Fishing vessel: Recall: 61.321% Precision: 63.725% Specificity: 98.633% Dice: 62.500%
# > Dump truck: Recall: 50.270% Precision: 49.733% Specificity: 96.422% Dice: 50.000%
# > Excavator: Recall: 67.797% Precision: 65.041% Specificity: 98.404% Dice: 66.390%
# > Building: Recall: 71.058% Precision: 67.193% Specificity: 91.773% Dice: 69.071%
# > Helipad: Recall: 64.706% Precision: 78.571% Specificity: 99.893% Dice: 70.968%
# > Storage tank: Recall: 63.636% Precision: 71.795% Specificity: 97.878% Dice: 67.470%
# > Shipping container: Recall: 59.825% Precision: 61.712% Specificity: 96.709% Dice: 60.754%
# > Pylon: Recall: 82.979% Precision: 84.783% Specificity: 99.747% Dice: 83.871%

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

anns = []
root_dir = './xview_recognition/'
test_dir = os.path.join(root_dir, 'xview_test')
for (dirpath, dirnames, filenames) in os.walk(test_dir):
    for filename in filenames:
        rel_dir = os.path.relpath(dirpath, root_dir)
        clean_filename = os.path.join(rel_dir, filename)
        image = GenericImage(clean_filename)
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = os.path.basename(dirpath)
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
import numpy as np
import tensorflow as tf

model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
all_test_images = []
metadata = []
ann_id = 0

print("Préparation des images de test...")
for idx, ann in enumerate(anns):
    predictions_data["images"][idx] = {
        "image_id": ann.filename.split('/')[-1],
        "filename": ann.filename,
        "width": int(ann.tile[2]),
        "height": int(ann.tile[3])
    }

    image_raw = load_geoimage(ann.filename)
    img = image_raw.astype(np.float32)
    if img.ndim == 4:
        img = img.squeeze(0)
    img_max = img.max()
    if img_max > 1.0:
        img = img / 255.0 if img_max <= 255.0 else img / 65535.0

    img_resized = tf.image.resize(tf.convert_to_tensor(img), [96, 96], method='lanczos3')
    img_final = img_resized.numpy()

    for obj_pred in ann.objects:
        all_test_images.append(img_final)
        metadata.append({
            "image_id": ann.filename.split('/')[-1],
            "bbox": [int(x) for x in obj_pred.bb]
        })

if all_test_images:
    X_test = np.array(all_test_images)
    print(f"Prédiction en cours sur {len(X_test)} détections...")
    all_preds = model.predict(X_test, batch_size=128, verbose=1)
    category_names = list(categories.values())
    for i, pred in enumerate(all_preds):
        predictions_data["annotations"][ann_id] = {
            "image_id": metadata[i]["image_id"],
            "category_id": category_names[np.argmax(pred)],
            "bbox": metadata[i]["bbox"]
        }
        ann_id += 1
print("Test terminé.")
# Out:
# Préparation des images de test...
# Prédiction en cours sur 2365 détections...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step
# Test terminé.

# %%
import json
with open('prediction.json', 'w') as f:
    json.dump(predictions_data, f)
