# %% [markdown]
# ## Assignment: Object detection
# - Alumno 1:
# - Alumno 2:
# - Alumno 3:
#
# The goals of the assignment are:
# * Put into practice acquired knowledge to detect and recognize objects of interest within a satellite image.
#
# To address this problem, you must choose one of the following options:
# *	Implement a sliding window strategy to process the whole image, and then train a classifier that determines whether each window includes or not an object of interest. In this way, you can use previous image classification model to infer the object category.
# *	Build a single-stage object detection model (e.g., YOLO, SSD, RetinaNet, etc.).
# *	Build a two-stage object detection model (e.g., Faster R-CNN, R-FCN, etc.).
#
# Follow the link below to download the detection data set “xview_detection”: [https://drive.upm.es/s/P7nEf3Bygns7tbM](https://drive.upm.es/s/P7nEf3Bygns7tbM)

# %%
import tensorflow as tf
import keras_cv

tf.keras.mixed_precision.set_global_policy('mixed_float16')

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)

tf.random.set_seed(42)
# Out:
# 2026-03-22 11:45:37.940935: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774179938.300355      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774179938.393354      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774179939.233982      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774179939.234022      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774179939.234025      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774179939.234027      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import requests
import zipfile
import json

url = 'https://drive.upm.es/s/P7nEf3Bygns7tbM/download'
zip_name = 'dataset.zip'
target_file = 'xview_det_train.json'
found_path = None

for root, dirs, files in os.walk("."):
    if target_file in files:
        found_path = os.path.join(root, target_file)
        break

if not found_path:
    if not os.path.exists(zip_name):
        r = requests.get(url, stream=True)
        with open(zip_name, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024):
                f.write(chunk)

    if os.path.getsize(zip_name) < 10000:
        print(f"ERREUR : Le fichier {zip_name} est trop petit. Le lien est invalide ou nécessite une connexion.")
    else:
        # Extraction uniquement si le fichier json n'avait pas été trouvé
        with zipfile.ZipFile(zip_name, 'r') as z:
            z.extractall(".")

        for root, dirs, files in os.walk("."):
            if target_file in files:
                found_path = os.path.join(root, target_file)
                break

if found_path:
    print(f"SUCCÈS : Fichier trouvé à : {found_path}")
    
    with open(found_path) as ifs:
        json_data = json.load(ifs)
    print("Base de données chargée avec succès !")
else:
    print(f"ERREUR : {target_file} reste introuvable après extraction.")
# Out:
# SUCCÈS : Fichier trouvé à : ./xview_det_train.json
# Base de données chargée avec succès !

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Small car', 1: 'Bus', 2: 'Truck', 3: 'Building'}

# %%
import warnings
import rasterio
import numpy as np
import os

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    full_path = os.path.join(BASE_DIR, filename) if ('BASE_DIR' in globals() and BASE_DIR is not None) else filename
    with rasterio.open(full_path, 'r') as src:   # ← context manager
        img = np.zeros((src.height, src.width, src.count), dtype=np.float32)
        for b in range(src.count):
            band = src.read(b + 1).astype(np.float32)
            bmin, bmax = band.min(), band.max()
            img[:, :, b] = (band - bmin) / (bmax - bmin + 1e-6) * 255.0
    return img.astype(np.uint8)

# %% [markdown]
# #### Training
# Design and train a detector to deal with the “xview_detection” perception task.

# %%
import json
import os

json_file = found_path if ('found_path' in globals() and found_path is not None) else '../PROJECT/xview_detection/xview_det_train.json'
if not os.path.exists(json_file):
    raise FileNotFoundError(f"Le fichier json de dataset est introuvable: {json_file}")

with open(json_file) as ifs:
    json_data = json.load(ifs)

BASE_DIR = os.path.dirname(json_file)
print("BASE_DIR:", BASE_DIR)
# Out:
# BASE_DIR: .

# %%
import numpy as np
from collections import defaultdict

ann_index = defaultdict(list)
for ann_elem in json_data['annotations'].values():
    ann_index[ann_elem['image_id']].append(ann_elem)

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img in json_data['images'].values():
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    for json_ann in ann_index[json_img['image_id']]:
        obj = GenericObject()
        obj.id = json_ann['image_id']
        obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]),
                  int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
        obj.category = json_ann['category_id']
        counts[obj.category] += 1
        image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Small car': 188300, 'Bus': 6269, 'Truck': 10600, 'Building': 275943}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)

# Bus et Truck sont les classes les plus rares dans xView
bus_truck_anns = [a for a in anns_train if any(
    o.category in ['Bus', 'Truck'] for o in a.objects
)]
anns_train = anns_train + bus_truck_anns * 2

print('Training images:', len(anns_train))
print('Validation images:', len(anns_valid))
print(f'Bus/Truck images ajoutées: {len(bus_truck_anns)*5}')
# Out:
# Training images: 13389
# Validation images: 761
# Bus/Truck images ajoutées: 16360

# %%
import keras_cv

print('Load model')
prediction_decoder = keras_cv.layers.NonMaxSuppression(
    bounding_box_format='xyxy',
    from_logits=False,
    confidence_threshold=0.01,
    iou_threshold=0.5
)
model = keras_cv.models.RetinaNet(
    num_classes=len(categories),
    bounding_box_format='xyxy',
    backbone=keras_cv.models.ResNet50Backbone.from_preset(
        'resnet50_imagenet',
        load_weights=True
    ),
    prediction_decoder=prediction_decoder
)
model.summary()
# Out:
# Load model
# I0000 00:00:1774180147.927195      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "retina_net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ images (InputLayer) │ (None, None,      │          0 │ -                 │
# │                     │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional          │ [(None, None,     │ 23,561,152 │ images[0][0]      │
# │ (Functional)        │ None, 512),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 1024),      │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 2048)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ feature_pyramid     │ [(None, None,     │  7,997,440 │ functional[0][0], │
# │ (FeaturePyramid)    │ None, 256),       │            │ functional[0][1], │
# │                     │ (None, None,      │            │ functional[0][2]  │
# │                     │ None, 256),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 256),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 256),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 256)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ prediction_head_1   │ (None, None,      │  1,853,220 │ feature_pyramid[… │
# │ (PredictionHead)    │ None, 36)         │            │ feature_pyramid[… │
# │                     │                   │            │ feature_pyramid[… │
# │                     │                   │            │ feature_pyramid[… │
# │                     │                   │            │ feature_pyramid[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ prediction_head     │ (None, None,      │  1,853,220 │ feature_pyramid[… │
# │ (PredictionHead)    │ None, 36)         │            │ feature_pyramid[… │
# │                     │                   │            │ feature_pyramid[… │
# │                     │                   │            │ feature_pyramid[… │
# │                     │                   │            │ feature_pyramid[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, None, 4)   │          0 │ prediction_head_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, None, 4)   │          0 │ prediction_head_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, None, 4)   │          0 │ prediction_head_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, None, 4)   │          0 │ prediction_head_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, None, 4)   │          0 │ prediction_head_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, None, 4)   │          0 │ prediction_head[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, None, 4)   │          0 │ prediction_head[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, None, 4)   │          0 │ prediction_head[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_7 (Reshape) │ (None, None, 4)   │          0 │ prediction_head[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_9 (Reshape) │ (None, None, 4)   │          0 │ prediction_head[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ box (Concatenate)   │ (None, None, 4)   │          0 │ reshape[0][0],    │
# │                     │                   │            │ reshape_2[0][0],  │
# │                     │                   │            │ reshape_4[0][0],  │
# │                     │                   │            │ reshape_6[0][0],  │
# │                     │                   │            │ reshape_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classification      │ (None, None, 4)   │          0 │ reshape_1[0][0],  │
# │ (Concatenate)       │                   │            │ reshape_3[0][0],  │
# │                     │                   │            │ reshape_5[0][0],  │
# │                     │                   │            │ reshape_7[0][0],  │
# │                     │                   │            │ reshape_9[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 35,265,032 (134.53 MB)
#  Trainable params: 35,211,912 (134.32 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
batch_size = 12

# Geler seulement les 40% premiers (ResNet101 a plus de couches)
layers = model.backbone.layers
freeze_until = int(len(layers) * 0.4)
for layer in layers[:freeze_until]:
    layer.trainable = False
for layer in layers[freeze_until:]:
    layer.trainable = True

# Cosine decay avec warmup
total_steps_phase1 = (len(anns_train) // batch_size) * 10
lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-4,
    decay_steps=total_steps_phase1,
    alpha=1e-6
)

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=lr_schedule,
        weight_decay=1e-4
    ),
    classification_loss='focal',
    box_loss='smoothl1',
    jit_compile=False
)

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ModelCheckpoint

model_checkpoint = ModelCheckpoint(
    'model.keras', monitor='val_loss', verbose=1, save_best_only=True
)
early_stop = EarlyStopping(
    'val_loss', patience=10, verbose=1, restore_best_weights=True
)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, early_stop, terminate]

# %%
def image_generator(filename, tile, bboxes, categories):
    def load_tiff(filepath):
        img = load_geoimage(filepath.numpy().decode('utf-8'))
        h, w = img.shape[:2]
        if h < 640 or w < 640:
            pad = np.zeros((640, 640, 3), dtype=np.uint8)
            pad[:h, :w] = img
            img = pad
        return img.astype(np.float32)
    img = tf.py_function(load_tiff, [filename], tf.float32)
    img.set_shape([640, 640, 3])
    return {
        'images': img,
        'bounding_boxes': {
            'boxes': bboxes,
            'classes': categories
        }
    }

def ragged_to_dense(inputs):
    from keras_cv import bounding_box
    images = inputs['images']
    if isinstance(images, tf.RaggedTensor):
        images = images.to_tensor()
    # Forcer float32 en sortie du pipeline
    images = tf.cast(images, tf.float32)
    return {
        'images': images,
        'bounding_boxes': bounding_box.to_dense(inputs['bounding_boxes'], max_boxes=100)
    }

def to_images_only(inputs):
    return inputs['images']

def retinanet_format(inputs):
    return inputs['images'], inputs['bounding_boxes']

_aug_flip = keras_cv.layers.RandomFlip(
    mode='horizontal_and_vertical',
    bounding_box_format='xyxy'
)
_aug_cutout = keras_cv.layers.RandomCutout(
    height_factor=(0.05, 0.20),
    width_factor=(0.05, 0.20),
)
_aug_color_deg = keras_cv.layers.RandomColorDegeneration(factor=0.4)

def _ensure_float32(inputs):
    # Garantit float32 après chaque layer keras_cv qui peut caster en float16
    images = tf.cast(inputs['images'], tf.float32)
    boxes  = inputs['bounding_boxes']
    return {
        'images': images,
        'bounding_boxes': {
            'boxes':   tf.cast(boxes['boxes'],   tf.float32),
            'classes': tf.cast(boxes['classes'], tf.float32)
        }
    }

def _manual_jitter(inputs):
    inputs = _ensure_float32(inputs)
    images = inputs['images']
    boxes  = inputs['bounding_boxes']

    scale    = tf.random.uniform([], 0.6, 1.0)
    crop_h   = tf.cast(640.0 * scale, tf.int32)
    crop_w   = tf.cast(640.0 * scale, tf.int32)
    offset_y = tf.random.uniform([], 0, 640 - crop_h, dtype=tf.int32)
    offset_x = tf.random.uniform([], 0, 640 - crop_w, dtype=tf.int32)

    images = tf.image.crop_to_bounding_box(images, offset_y, offset_x, crop_h, crop_w)
    images = tf.image.resize(images, [640, 640])

    oy  = tf.cast(offset_y, tf.float32)
    ox  = tf.cast(offset_x, tf.float32)
    ch  = tf.cast(crop_h,   tf.float32)
    cw  = tf.cast(crop_w,   tf.float32)
    raw = tf.cast(boxes['boxes'], tf.float32)

    x1 = tf.clip_by_value((raw[..., 0] - ox) / cw * 640.0, 0.0, 640.0)
    y1 = tf.clip_by_value((raw[..., 1] - oy) / ch * 640.0, 0.0, 640.0)
    x2 = tf.clip_by_value((raw[..., 2] - ox) / cw * 640.0, 0.0, 640.0)
    y2 = tf.clip_by_value((raw[..., 3] - oy) / ch * 640.0, 0.0, 640.0)

    return {
        'images': images,
        'bounding_boxes': {
            'boxes':   tf.stack([x1, y1, x2, y2], axis=-1),
            'classes': tf.cast(boxes['classes'], tf.float32)
        }
    }

def _add_noise(inputs):
    inputs = _ensure_float32(inputs)
    images = inputs['images']
    noise  = tf.random.normal(shape=tf.shape(images), mean=0.0, stddev=10.0, dtype=tf.float32)
    images = tf.clip_by_value(images + noise, 0.0, 255.0)
    return {**inputs, 'images': images}

def _augment_hsv(inputs):
    image = tf.cast(inputs['images'], tf.float32) / 255.0
    image = tf.image.random_hue(image, max_delta=0.02)
    image = tf.image.random_saturation(image, lower=0.4, upper=1.6)
    image = tf.image.random_brightness(image, max_delta=0.4)
    image = tf.image.random_contrast(image, lower=0.7, upper=1.3)
    image = tf.clip_by_value(image, 0.0, 1.0) * 255.0
    return {**inputs, 'images': image}

def data_augmentation(inputs):
    inputs = _ensure_float32(inputs)
    inputs = _aug_flip(inputs)
    inputs = _ensure_float32(inputs)
    inputs = _manual_jitter(inputs)
    inputs = _ensure_float32(inputs)
    inputs = _aug_cutout(inputs)
    inputs = _ensure_float32(inputs)
    inputs = _aug_color_deg(inputs)
    inputs = _ensure_float32(inputs)
    inputs = _add_noise(inputs)
    return inputs

# %%
batch_size = 12

def xywh_to_xyxy(bb):
    x, y, w, h = bb
    return [x, y, x + w, y + h]

filenames_train, tiles_train, bboxes_train, categories_train = zip(*list(map(
    lambda img_ann: (
        img_ann.filename,
        list(img_ann.tile),
        list([xywh_to_xyxy(obj_ann.bb) for obj_ann in img_ann.objects]),
        list([list(categories.keys())[list(categories.values()).index(obj_ann.category)]
              for obj_ann in img_ann.objects])
    ), anns_train)))

filenames_valid, tiles_valid, bboxes_valid, categories_valid = zip(*list(map(
    lambda img_ann: (
        img_ann.filename,
        list(img_ann.tile),
        list([xywh_to_xyxy(obj_ann.bb) for obj_ann in img_ann.objects]),
        list([list(categories.keys())[list(categories.values()).index(obj_ann.category)]
              for obj_ann in img_ann.objects])
    ), anns_valid)))

ds_train = tf.data.Dataset.from_tensor_slices((
    tf.cast(filenames_train, tf.string),
    tf.cast(tiles_train, tf.int32),
    tf.cast(tf.ragged.constant(bboxes_train), tf.float32).to_tensor(default_value=-1.0),
    tf.cast(tf.ragged.constant(categories_train), tf.float32).to_tensor(default_value=-1.0)
))
ds_valid = tf.data.Dataset.from_tensor_slices((
    tf.cast(filenames_valid, tf.string),
    tf.cast(tiles_valid, tf.int32),
    tf.cast(tf.ragged.constant(bboxes_valid), tf.float32).to_tensor(default_value=-1.0),
    tf.cast(tf.ragged.constant(categories_valid), tf.float32).to_tensor(default_value=-1.0)
))

ds_train = ds_train.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.map(_augment_hsv, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache('/tmp/ds_train_cache')
ds_train = ds_train.ragged_batch(batch_size=batch_size, drop_remainder=True)
ds_train = ds_train.map(data_augmentation, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.map(ragged_to_dense, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.map(retinanet_format, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

ds_valid = ds_valid.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE)
ds_valid = ds_valid.ragged_batch(batch_size=batch_size, drop_remainder=True)
ds_valid = ds_valid.map(ragged_to_dense, num_parallel_calls=tf.data.AUTOTUNE)
ds_valid = ds_valid.map(retinanet_format, num_parallel_calls=tf.data.AUTOTUNE)
ds_valid = ds_valid.prefetch(tf.data.AUTOTUNE)

# %%
# Ajoute cette cellule avant model.fit pour vérifier
print(f"Steps par epoch train : {len(ds_train)}")
print(f"Steps par epoch valid : {len(ds_valid)}")

import subprocess
r = subprocess.run(['nvidia-smi', '--query-gpu=memory.used,memory.total',
                    '--format=csv,noheader'], capture_output=True, text=True)
print("VRAM:", r.stdout.strip())
# Out:
# Steps par epoch train : 1115
# Steps par epoch valid : 63
# VRAM: 515 MiB, 16384 MiB

# %%
import numpy as np

print('Phase 1 : backbone partiellement gelé')
epochs_phase1 = 10
h1 = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=epochs_phase1,
    callbacks=callbacks,
    verbose=1
)

print('\nDégel total, BatchNorm gelées, LR cosine 1e-6 → 1e-8')
for layer in model.backbone.layers:
    # Dégeler tout sauf BatchNorm
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = False   # BatchNorm reste en mode inférence
    else:
        layer.trainable = True

total_steps_phase2 = (len(anns_train) // batch_size) * 15
lr2 = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate=1e-6,   # 1e-5 → 1e-6 : plus prudent
    decay_steps=total_steps_phase2,
    alpha=1e-8
)
model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=lr2, weight_decay=1e-4),
    classification_loss='focal',
    box_loss='smoothl1',
    jit_compile=False
)

early_stop2 = EarlyStopping('val_loss', patience=7, verbose=1, restore_best_weights=True)

print('Phase 2 : fine-tuning complet')
h2 = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=15,
    callbacks=[model_checkpoint, early_stop2, terminate],
    verbose=1
)
# Out:
# Phase 1 : backbone partiellement gelé
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: {'images': 'images'}
# Received: inputs=Tensor(shape=(12, 640, 640, 3))
#   warnings.warn(msg)
# I0000 00:00:1774180200.438249      68 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.5909 - classification_loss: 0.3965 - loss: 0.9874
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: {'images': 'images'}
# Received: inputs=Tensor(shape=(12, 640, 640, 3))
#   warnings.warn(msg)
# Epoch 1: val_loss improved from inf to 1.24910, saving model to model.keras
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1340s 1s/step - box_loss: 0.5909 - classification_loss: 0.3965 - loss: 0.9873 - val_box_loss: 0.6365 - val_classification_loss: 0.6126 - val_loss: 1.2491
# Epoch 2/10
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - box_loss: 0.5483 - classification_loss: 0.2893 - loss: 0.8377
# Epoch 2: val_loss improved from 1.24910 to 1.17973, saving model to model.keras
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 977s 874ms/step - box_loss: 0.5483 - classification_loss: 0.2893 - loss: 0.8377 - val_box_loss: 0.6052 - val_classification_loss: 0.5745 - val_loss: 1.1797
# Epoch 3/10
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - box_loss: 0.5301 - classification_loss: 0.2740 - loss: 0.8042
# Epoch 3: val_loss improved from 1.17973 to 1.08676, saving model to model.keras
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1039s 930ms/step - box_loss: 0.5301 - classification_loss: 0.2740 - loss: 0.8042 - val_box_loss: 0.5510 - val_classification_loss: 0.5357 - val_loss: 1.0868
# Epoch 4/10
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - box_loss: 0.5137 - classification_loss: 0.2645 - loss: 0.7782
# Epoch 4: val_loss improved from 1.08676 to 1.03359, saving model to model.keras
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 956s 855ms/step - box_loss: 0.5137 - classification_loss: 0.2645 - loss: 0.7782 - val_box_loss: 0.5557 - val_classification_loss: 0.4778 - val_loss: 1.0336
# Epoch 5/10
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - box_loss: 0.5015 - classification_loss: 0.2555 - loss: 0.7570
# Epoch 5: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 954s 854ms/step - box_loss: 0.5015 - classification_loss: 0.2555 - loss: 0.7570 - val_box_loss: 0.5467 - val_classification_loss: 0.4877 - val_loss: 1.0343
# Epoch 6/10
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - box_loss: 0.4900 - classification_loss: 0.2473 - loss: 0.7374
# Epoch 6: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 955s 855ms/step - box_loss: 0.4900 - classification_loss: 0.2473 - loss: 0.7374 - val_box_loss: 0.5884 - val_classification_loss: 0.5051 - val_loss: 1.0935
# Epoch 7/10
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - box_loss: 0.4787 - classification_loss: 0.2406 - loss: 0.7194
# Epoch 7: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 953s 853ms/step - box_loss: 0.4787 - classification_loss: 0.2406 - loss: 0.7194 - val_box_loss: 0.5709 - val_classification_loss: 0.4812 - val_loss: 1.0521
# Epoch 8/10
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4689 - classification_loss: 0.2338 - loss: 0.7027
# Epoch 8: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1535s 1s/step - box_loss: 0.4689 - classification_loss: 0.2338 - loss: 0.7027 - val_box_loss: 0.5585 - val_classification_loss: 0.4992 - val_loss: 1.0578
# Epoch 9/10
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - box_loss: 0.4617 - classification_loss: 0.2287 - loss: 0.6904
# Epoch 9: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 951s 851ms/step - box_loss: 0.4617 - classification_loss: 0.2287 - loss: 0.6904 - val_box_loss: 0.5583 - val_classification_loss: 0.5014 - val_loss: 1.0597
# Epoch 10/10
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4596 - classification_loss: 0.2271 - loss: 0.6867
# Epoch 10: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1489s 1s/step - box_loss: 0.4596 - classification_loss: 0.2271 - loss: 0.6867 - val_box_loss: 0.5609 - val_classification_loss: 0.5097 - val_loss: 1.0706
# Restoring model weights from the end of the best epoch: 4.
#
# Dégel total, LR cosine 1e-5 → 1e-7
# Phase 2 : fine-tuning complet
# Epoch 1/15
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: {'images': 'images'}
# Received: inputs=Tensor(shape=(12, 640, 640, 3))
#   warnings.warn(msg)
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.5092 - classification_loss: 0.2629 - loss: 0.7722
# Epoch 1: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1438s 1s/step - box_loss: 0.5092 - classification_loss: 0.2629 - loss: 0.7722 - val_box_loss: 0.5951 - val_classification_loss: 45.7481 - val_loss: 46.3432
# Epoch 2/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.5005 - classification_loss: 0.2541 - loss: 0.7546
# Epoch 2: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1387s 1s/step - box_loss: 0.5005 - classification_loss: 0.2541 - loss: 0.7546 - val_box_loss: 0.5922 - val_classification_loss: 35.9665 - val_loss: 36.5588
# Epoch 3/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4978 - classification_loss: 0.2508 - loss: 0.7486
# Epoch 3: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1603s 1s/step - box_loss: 0.4978 - classification_loss: 0.2508 - loss: 0.7486 - val_box_loss: 0.6290 - val_classification_loss: 101.2217 - val_loss: 101.8507
# Epoch 4/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4952 - classification_loss: 0.2499 - loss: 0.7450
# Epoch 4: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1628s 1s/step - box_loss: 0.4952 - classification_loss: 0.2499 - loss: 0.7450 - val_box_loss: 0.5954 - val_classification_loss: 38.6494 - val_loss: 39.2448
# Epoch 5/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4918 - classification_loss: 0.2469 - loss: 0.7387
# Epoch 5: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1407s 1s/step - box_loss: 0.4918 - classification_loss: 0.2469 - loss: 0.7387 - val_box_loss: 0.5763 - val_classification_loss: 28.6638 - val_loss: 29.2401
# Epoch 6/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4886 - classification_loss: 0.2450 - loss: 0.7336
# Epoch 6: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1381s 1s/step - box_loss: 0.4886 - classification_loss: 0.2450 - loss: 0.7336 - val_box_loss: 0.5940 - val_classification_loss: 48.3015 - val_loss: 48.8955
# Epoch 7/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4868 - classification_loss: 0.2438 - loss: 0.7306
# Epoch 7: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1382s 1s/step - box_loss: 0.4868 - classification_loss: 0.2438 - loss: 0.7306 - val_box_loss: 0.5903 - val_classification_loss: 68.1074 - val_loss: 68.6977
# Epoch 8/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4842 - classification_loss: 0.2420 - loss: 0.7261
# Epoch 8: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1615s 1s/step - box_loss: 0.4842 - classification_loss: 0.2420 - loss: 0.7261 - val_box_loss: 0.5917 - val_classification_loss: 36.2225 - val_loss: 36.8142
# Epoch 9/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4828 - classification_loss: 0.2413 - loss: 0.7242
# Epoch 9: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1385s 1s/step - box_loss: 0.4828 - classification_loss: 0.2414 - loss: 0.7242 - val_box_loss: 0.5949 - val_classification_loss: 40.7428 - val_loss: 41.3377
# Epoch 10/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4807 - classification_loss: 0.2393 - loss: 0.7200
# Epoch 10: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1382s 1s/step - box_loss: 0.4807 - classification_loss: 0.2393 - loss: 0.7200 - val_box_loss: 0.5929 - val_classification_loss: 37.5356 - val_loss: 38.1285
# Epoch 11/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4794 - classification_loss: 0.2391 - loss: 0.7185
# Epoch 11: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1604s 1s/step - box_loss: 0.4794 - classification_loss: 0.2391 - loss: 0.7185 - val_box_loss: 0.5970 - val_classification_loss: 40.5860 - val_loss: 41.1831
# Epoch 12/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4797 - classification_loss: 0.2386 - loss: 0.7183
# Epoch 12: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1387s 1s/step - box_loss: 0.4797 - classification_loss: 0.2386 - loss: 0.7183 - val_box_loss: 0.5839 - val_classification_loss: 27.3081 - val_loss: 27.8921
# Epoch 13/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4784 - classification_loss: 0.2385 - loss: 0.7169
# Epoch 13: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1382s 1s/step - box_loss: 0.4784 - classification_loss: 0.2385 - loss: 0.7169 - val_box_loss: 0.5924 - val_classification_loss: 38.0535 - val_loss: 38.6458
# Epoch 14/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4780 - classification_loss: 0.2385 - loss: 0.7165
# Epoch 14: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1384s 1s/step - box_loss: 0.4780 - classification_loss: 0.2385 - loss: 0.7165 - val_box_loss: 0.5902 - val_classification_loss: 33.4964 - val_loss: 34.0866
# Epoch 15/15
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - box_loss: 0.4777 - classification_loss: 0.2384 - loss: 0.7162
# Epoch 15: val_loss did not improve from 1.03359
# 1115/1115 ━━━━━━━━━━━━━━━━━━━━ 1381s 1s/step - box_loss: 0.4777 - classification_loss: 0.2384 - loss: 0.7162 - val_box_loss: 0.5938 - val_classification_loss: 37.0317 - val_loss: 37.6255
# Restoring model weights from the end of the best epoch: 12.

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as col
import numpy as np
# %matplotlib inline

def area_intersection(boxes, box):
    xmin = np.maximum(np.min(boxes[:, 0::2], axis=1), np.min(box[0::2]))
    ymin = np.maximum(np.min(boxes[:, 1::2], axis=1), np.min(box[1::2]))
    xmax = np.minimum(np.max(boxes[:, 0::2], axis=1), np.max(box[0::2]))
    ymax = np.minimum(np.max(boxes[:, 1::2], axis=1), np.max(box[1::2]))
    w = np.maximum(xmax - xmin + 1.0, 0.0)
    h = np.maximum(ymax - ymin + 1.0, 0.0)
    return w * h

def area_union(boxes, box):
    area_anns = (np.max(box[0::2])-np.min(box[0::2])+1.0) * (np.max(box[1::2])-np.min(box[1::2])+1.0)
    area_pred = (np.max(boxes[:, 0::2], axis=1)-np.min(boxes[:, 0::2], axis=1)+1.0) * (np.max(boxes[:, 1::2], axis=1)-np.min(boxes[:, 1::2], axis=1)+1.0)
    return area_anns + area_pred - area_intersection(boxes, box)

def calc_iou(boxes, box):
    iou = area_intersection(boxes, box) / area_union(boxes, box)
    max_value = np.max(iou)
    max_index = np.argmax(iou)
    return max_value, max_index

def calc_ap(rec, prec):
    # First append sentinel values at the end
    mrec = np.concatenate(([0.0], rec, [1.0]))
    mpre = np.concatenate(([0.0], prec, [0.0]))
    # Compute the precision envelope
    for i in range(mpre.size-1, 0, -1):
        mpre[i-1] = np.maximum(mpre[i-1], mpre[i])
    # To calculate area under PR curve, look for points where X axis (recall) changes value
    i = np.where(mrec[1:] != mrec[:-1])[0]
    # and sum (\Delta recall) * prec
    ap = np.sum((mrec[i+1] - mrec[i]) * mpre[i+1])
    return ap

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=categories, yticklabels=categories, ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

def draw_precision_recall(precisions, recalls, categories):
    # Draw precision-recall curves for each category
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    plt.axis([0, 1, 0, 1])
    c_dark = list(filter(lambda x: x.startswith('dark'), col.cnames.keys()))
    aps = []
    # Compare categories for a specific algorithm
    for idx in range(len(categories)):
        plt.plot(recalls[idx], precisions[idx], color=c_dark[idx], label=categories[idx], linewidth=4.0)
        aps.append(calc_ap(recalls[idx], precisions[idx]))
    handles, labels = ax.get_legend_handles_labels()
    labels = [str(val + ' [' + "{:.3f}".format(aps[idx]) + ']') for idx, val in enumerate(labels)]
    handles = [h for (ap, h) in sorted(zip(aps, handles), key=lambda x: x[0], reverse=True)]
    labels = [l for (ap, l) in sorted(zip(aps, labels), key=lambda x: x[0], reverse=True)]
    leg = plt.legend(handles, labels, loc='upper right')
    leg.set_zorder(100)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid("on", linestyle="--", linewidth=2.0)
    fig.tight_layout()
    plt.show()

# %%
import numpy as np
from tqdm import tqdm

model = tf.keras.models.load_model('model.keras')
model._prediction_decoder = keras_cv.layers.NonMaxSuppression(
    bounding_box_format='xyxy',
    from_logits=False,
    confidence_threshold=0.01,
    iou_threshold=0.5
)

INFER_BATCH = 12

ds_valid_infer = tf.data.Dataset.from_tensor_slices((
    tf.cast(filenames_valid, tf.string),
    tf.cast(tiles_valid, tf.int32),
    tf.cast(tf.ragged.constant(bboxes_valid), tf.float32).to_tensor(default_value=-1.0),
    tf.cast(tf.ragged.constant(categories_valid), tf.float32).to_tensor(default_value=-1.0)
))
ds_valid_infer = ds_valid_infer.map(image_generator, num_parallel_calls=4)
ds_valid_infer = ds_valid_infer.batch(batch_size=INFER_BATCH)
ds_valid_infer = ds_valid_infer.map(ragged_to_dense, num_parallel_calls=4)
# Ne pas appeler to_images_only — passer le dict complet {'images': ...}
ds_valid_infer = ds_valid_infer.map(
    lambda x: x['images'], num_parallel_calls=4   # extrait juste les images
).prefetch(2)

all_preds = model.predict(ds_valid_infer, verbose=1)

annotations, predictions = {}, {}
for idx, ann in enumerate(tqdm(anns_valid)):
    annotations.setdefault(ann.filename, {})
    predictions.setdefault(ann.filename, {})
    for obj in ann.objects:
        annotations[ann.filename].setdefault(obj.category, {'bbox': []})
        annotations[ann.filename][obj.category]['bbox'].append(xywh_to_xyxy(obj.bb))

    n_det = int(np.squeeze(all_preds['num_detections'])[idx])
    for i in range(n_det):
        obj = GenericObject()
        bbox = all_preds['boxes'][idx][i]
        obj.bb = (bbox[0], bbox[1], bbox[2], bbox[3])
        obj.category = categories[int(all_preds['classes'][idx][i])]
        obj.score = float(all_preds['confidence'][idx][i])
        predictions[ann.filename].setdefault(obj.category, {'bbox': [], 'confidence': []})
        predictions[ann.filename][obj.category]['bbox'].append(obj.bb)
        predictions[ann.filename][obj.category]['confidence'].append(obj.score)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/serialization_lib.py:734: UserWarning: `compile()` was not called as part of model loading because the model's `compile()` method is custom. All subclassed Models that have `compile()` overridden should also override `get_compile_config()` and `compile_from_config(config)`. Alternatively, you can call `compile()` manually after loading.
#   instance.compile_from_config(compile_config)
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: {'images': 'images'}
# Received: inputs=Tensor(shape=(8, 640, 640, 3))
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_24/3129456204.py in <cell line: 0>()
#      29 ds_valid_infer = ds_valid_infer.map(to_images_only, num_parallel_calls=4).prefetch(2)
#      30
# ---> 31 all_preds = model.predict(ds_valid_infer, verbose=1)
#      32
#      33 annotations, predictions = {}, {}
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras_cv/src/models/object_detection/retinanet/retinanet.py in predict_step(self, *args)
#     250             return self.decode_predictions(outputs[0], args[-1]), outputs[1]
#     251         else:
# --> 252             return self.decode_predictions(outputs, args[-1])
#     253
#     254     @property
#
# /usr/local/lib/python3.12/dist-packages/keras_cv/src/models/object_detection/retinanet/retinanet.py in decode_predictions(self, predictions, images)
#     294         anchors = ops.concatenate([a for a in anchors.values()], axis=0)
#     295
# --> 296         box_pred = _decode_deltas_to_boxes(
#     297             anchors=anchors,
#     298             boxes_delta=box_pred,
#
# /usr/local/lib/python3.12/dist-packages/keras_cv/src/bounding_box/converters.py in _decode_deltas_to_boxes(anchors, boxes_delta, anchor_format, box_format, variance, image_shape)
#     121         return boxes
#     122     else:
# --> 123         return decode_single_level(anchors, boxes_delta)
#     124
#     125
#
# /usr/local/lib/python3.12/dist-packages/keras_cv/src/bounding_box/converters.py in decode_single_level(anchor, box_delta)
#      97         )
#      98         if variance is not None:
# ---> 99             box_delta = box_delta * variance
#     100         # anchors be unbatched, boxes can either be batched or unbatched.
#     101         box = ops.concatenate(
#
# TypeError: Input 'y' of 'Mul' Op has type float32 that does not match type float16 of argument 'x'.

# %%
threshold = 0.5
default_cls = 'BACKGROUND'
y_true, y_pred = [], []  # confusion matrix
tps, confidences = dict(), dict()  # draw precision-recall curves for each category
for cls in categories.values():
    # Compute TP, FP and FN for each image
    tps[cls], confidences[cls] = [], []
    for f in predictions:
        # Sort 'cls' predictions by confidence for each file
        pred_boxes, pred_confidences = [], []
        if cls in predictions[f].keys():
            for idx in range(len(predictions[f][cls]['bbox'])):
                pred_boxes.append(predictions[f][cls]['bbox'][idx])
                pred_confidences.append(predictions[f][cls]['confidence'][idx])
            sorted_ind = np.argsort(-np.array(pred_confidences))
            pred_boxes = np.array(pred_boxes)[sorted_ind, :]
        pred_boxes = np.array(pred_boxes).astype(float)
        # Define 'cls' annotations for each file
        anno_boxes = []
        if cls in annotations[f].keys():
            anno_boxes = annotations[f][cls]['bbox']
        anno_boxes = np.array(anno_boxes).astype(float)
        # Define horizontal or oriented bounding boxes
        anno_indices = list(range(len(anno_boxes)))
        # Compare a single prediction 'pred_box' with all annotations 'anno_boxes'
        for pred_idx, pred_box in enumerate(pred_boxes):
            # A prediction is correct if its IoU with the ground truth is above the threshold
            iou_value, ann_index = calc_iou(anno_boxes, pred_box) if len(anno_boxes) > 0 else (-1, -1)
            if iou_value > threshold and ann_index in anno_indices:
                # TP
                anno_indices.remove(int(ann_index))
                tps[cls] += [1.0]
                y_true += [cls]
            else:
                # FP
                tps[cls] += [0.0]
                y_true += [default_cls]
            y_pred += [cls]
            confidences[cls] += [pred_confidences[pred_idx]]
        # FN
        y_true += [cls] * len(anno_indices)
        y_pred += [default_cls] * len(anno_indices)
y_true, y_pred = np.array(y_true), np.array(y_pred)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score

# Compute AP metric
precision_list, recall_list, ap_list = [], [], []
for cls in categories.values():
    sorted_ind = np.argsort(-np.array(confidences[cls]))
    tp = np.cumsum(np.array(tps[cls])[sorted_ind], dtype=float)
    recall = np.array([0.0]) if len(tp) == 0 else tp / np.maximum(np.sum(y_true == cls), np.finfo(np.float64).eps)
    precision = np.array([0.0]) if len(tp) == 0 else tp / np.maximum(list(range(1, np.sum(y_pred == cls)+1)), np.finfo(np.float64).eps)
    ap = calc_ap(recall, precision)
    print('> %s: Recall: %.3f%% Precision: %.3f%% AP: %.3f%%' % (cls, recall[-1]*100, precision[-1]*100, ap*100))
    precision_list.append(precision)
    recall_list.append(recall)
    ap_list.append(ap)
mean_ap = np.mean(ap_list)
print('mAccuracy: %.3f%%' % (accuracy_score(y_true, y_pred)*100))
print('mRecall: %.3f%%' % (recall_score(y_true, y_pred, average='macro', zero_division=1)*100))
print('mPrecision: %.3f%%' % (precision_score(y_true, y_pred, average='macro', zero_division=1)*100))
print('mAP: %.3f%%' % (mean_ap*100))

# %%
names = list(categories.values()).copy()
names.insert(0, default_cls)
cm = confusion_matrix(y_true, y_pred, labels=names)
print('Confusion matrix:')
print(cm)
draw_confusion_matrix(cm, names)
draw_precision_recall(precision_list, recall_list, categories)

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
import os
import numpy as np

# Cherche le dossier xview_test dans l'arborescence courante
test_dir = None
for root, dirs, files in os.walk('.'):
    if 'xview_test' in dirs:
        test_dir = os.path.join(root, 'xview_test')
        break

if test_dir is None:
    raise FileNotFoundError("Dossier xview_test introuvable. Vérifie l'extraction du dataset.")

anns = []
for (dirpath, dirnames, filenames) in os.walk(test_dir):
    for filename in filenames:
        # Chemin relatif à partir de la racine du dataset (même convention que le train)
        rel_path = os.path.relpath(os.path.join(dirpath, filename), start='.')
        image = GenericImage(rel_path)
        image.tile = np.array([0, 0, 640, 640])
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))

# %%
import numpy as np
from tqdm import tqdm
import json

model = tf.keras.models.load_model('model.keras')
model._prediction_decoder = keras_cv.layers.NonMaxSuppression(
    bounding_box_format='xyxy',
    from_logits=False,
    confidence_threshold=0.01,
    iou_threshold=0.35
)
model.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=3e-5, weight_decay=1e-4),
    classification_loss='focal',
    box_loss='smoothl1',
    jit_compile=False
)

filenames_test = [ann.filename for ann in anns]
tiles_test = [list(ann.tile) for ann in anns]
bboxes_test_empty = [[[0, 0, 0, 0]] for _ in anns]
cats_test_empty   = [[0] for _ in anns]

INFER_BATCH = 8

ds_test = tf.data.Dataset.from_tensor_slices((
    tf.cast(filenames_test, tf.string),
    tf.cast(tiles_test, tf.int32),
    tf.cast(tf.ragged.constant(bboxes_test_empty), tf.float32).to_tensor(default_value=-1.0),
    tf.cast(tf.ragged.constant(cats_test_empty),   tf.float32).to_tensor(default_value=-1.0)
))
ds_test = ds_test.map(image_generator, num_parallel_calls=4)
ds_test = ds_test.batch(batch_size=INFER_BATCH)
ds_test = ds_test.map(ragged_to_dense, num_parallel_calls=4)
ds_test = ds_test.map(to_images_only, num_parallel_calls=4).prefetch(2)

all_preds = model.predict(ds_test, verbose=1)

predictions = {}
predictions_data = {"images": {}, "annotations": {}, "categories": categories}
imgs_idx, annos_idx = 0, 0

for idx, ann in enumerate(tqdm(anns)):
    n_det = int(np.squeeze(all_preds['num_detections'])[idx])
    predictions.setdefault(ann.filename, {})
    num_objects = 0
    for i in range(n_det):
        bbox = all_preds['boxes'][idx][i]
        cat  = categories[int(all_preds['classes'][idx][i])]
        conf = float(all_preds['confidence'][idx][i])
        predictions[ann.filename].setdefault(cat, {'bbox': [], 'confidence': []})
        predictions[ann.filename][cat]['bbox'].append(bbox)
        predictions[ann.filename][cat]['confidence'].append(conf)
        num_objects += 1

    predictions_data["images"][imgs_idx] = {
        "image_id": ann.filename.split('/')[-1],
        "filename": ann.filename,
        "num_objects": num_objects,
        "width": 640, "height": 640
    }
    imgs_idx += 1
    for cat in predictions[ann.filename]:
        for i, (bb, conf) in enumerate(zip(
                predictions[ann.filename][cat]['bbox'],
                predictions[ann.filename][cat]['confidence'])):
            x1, y1, x2, y2 = int(bb[0]), int(bb[1]), int(bb[2]), int(bb[3])
            predictions_data["annotations"][annos_idx] = {
                "image_id": ann.filename.split('/')[-1],
                "category_id": cat,
                "bbox": (x1, y1, x2 - x1, y2 - y1),
                "confidence": str(conf)
            }
            annos_idx += 1

with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
print(f"Sauvegardé : {annos_idx} détections sur {imgs_idx} images")
